# %%
import torch
import torch.nn as nn
import torch.utils.data as Data
import torchvision
from torch.nn import functional as F
from torch.autograd import Variable
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
import numpy as np
import cv2
import datetime
import h5py
from scipy.stats.stats import pearsonr
import pytorch_ssim

# %%
# for plot figures
plt.rcParams.update({'figure.max_open_warning': 0})
plt.rcParams['svg.fonttype'] = 'none'
def adjust_spines(ax, spines):
    for loc, spine in ax.spines.items():
        if loc in spines:
            spine.set_position(('outward', 5))  
        else:
            spine.set_color('none')  
    if 'left' in spines:
        ax.yaxis.set_ticks_position('left')
    else:
        ax.yaxis.set_ticks([])
    if 'bottom' in spines:
        ax.xaxis.set_ticks_position('bottom')
    else:
        ax.xaxis.set_ticks([])

# %%
no_cuda=False
cuda = not no_cuda and torch.cuda.is_available()
device=torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
device_cpu=torch.device('cpu')
EPOCH = 50
LR=0.0001
L2=0.0
torch.backends.cudnn.benchmark = False
torch.cuda.manual_seed(1)
torch.backends.cudnn.deterministic=True
np.random.seed(1)
torch.manual_seed(1)

# %%
def img_real2view(img):
    gamma_correction=lambda x:np.power(x,1.0/2.2)
    img_shape=img.shape
    # gray image
    if np.size(img_shape)==2:
        #uint8
        if np.max(img)>1:
            temp_view=np.zeros_like(img,dtype=np.float32)
            temp_view=np.float32(img)/255.0#float32, 1.0
            temp_view=gamma_correction(temp_view)
            temp_view2=np.zeros_like(img,dtype=np.uint8)
            temp_view2=np.uint8(temp_view*255)
            return temp_view2
        #float
        if np.max(img)<2:
            return gamma_correction(img)
    #color image
    if np.size(img_shape)==3:
        #uint8
        if np.max(img)>1:
            temp_view=np.zeros_like(img,dtype=np.float32)
            temp_view=np.float32(img)/255.0#1.0
            temp_view=gamma_correction(temp_view)
            temp_view2=np.zeros_like(img,dtype=np.uint8)
            temp_view2=np.uint8(temp_view*255)#255
            return temp_view2
        #float
        if np.max(img)<2:
            return gamma_correction(img)

# %%
#read movie data sky
def read_movie_from_h5(filename):
    h5f = h5py.File(filename,'r')
    movie_bgr_h5=h5f['movie_bgr_real'][:]
    h5f.close()
    return movie_bgr_h5
movie_bgr_h5=read_movie_from_h5('../data/all_image_patches_lower_1f_28x28_bg_20200512.h5') 
print (movie_bgr_h5.shape)
# Out:
# (10000, 28, 28, 2)

# %%
fig, axes = plt.subplots(nrows=1, ncols=10,figsize=(12.5,2.5))
for ii in range(10):
    temp=np.zeros((28,28,3),np.uint8)
    temp[...,1:]=movie_bgr_h5[5000+ii,:,:,::-1]
    axes[ii].imshow(img_real2view(temp))
    axes[ii].grid(False)

# %%
#make train, val, test loader, make the dataset suitable for pytorch
movie_bgr_h5=np.transpose(movie_bgr_h5,(0,3,1,2))
train_loader=[]
for ii in range(0,9000,100):
    temp0=movie_bgr_h5[ii:ii+100]
    train_loader.append(temp0)
temp0=movie_bgr_h5[9000:9800]
val_loader=np.copy(temp0)
temp0=movie_bgr_h5[9800:]
test_loader=np.copy(temp0)

print ('length of train_loader:')
print (len(train_loader))
print ('shape of train_loader[0]:')
print (train_loader[0].shape)
print ('shape of val_loader:')
print (val_loader.shape)
print ('shape of test_loader:')
print (test_loader.shape)
# Out:
# length of train_loader:
# 90
# shape of train_loader[0]:
# (100, 2, 28, 28)
# shape of val_loader:
# (800, 2, 28, 28)
# shape of test_loader:
# (200, 2, 28, 28)

# %%
fig, axes = plt.subplots(nrows=1, ncols=10,figsize=(12.5,2.5))
for ii in range(10):
    temp=np.zeros((28,28,3),np.uint8)
    temp[...,1:]=np.transpose(train_loader[10][ii],(1,2,0))[...,::-1]
    axes[ii].imshow(img_real2view(temp))
    axes[ii].grid(False)

# %%
fig, axes = plt.subplots(nrows=1, ncols=10,figsize=(12.5,2.5))
for ii in range(10):
    temp=np.zeros((28,28,3),np.uint8)
    temp[...,1:]=np.transpose(test_loader[ii],(1,2,0))[...,::-1]
    axes[ii].imshow(img_real2view(temp))
    axes[ii].grid(False)

# %%
#define train_loader_length and val_loader_length for function model_train()
train_loader_length=len(train_loader)
val_loader_length=len(val_loader)
sky_bg_mean_f   =(0.10539950580232095, 0.23792787064825932)

# %%
#some help function
class Flatten(nn.Module):
    def forward(self, x):
        N, C, H, W = x.size() 
        return x.view(N, -1)  

class Unflatten(nn.Module):
    """
    An Unflatten module receives an input of shape (N, C*H*W) and reshapes it
    to produce an output of shape (N, C, H, W).
    """
    def __init__(self, N=-1, C=128, H=7, W=7):
        super(Unflatten, self).__init__()
        self.N = N
        self.C = C
        self.H = H
        self.W = W
    def forward(self, x):
        return x.view(self.N, self.C, self.H, self.W)


loss_mse = nn.MSELoss()
loss_ssim = pytorch_ssim.SSIM(window_size=3)

#loss with L2 and L1 regularizer
#something like loss = mseloss+ alpha*alpha_x(L2)+beta*beta_y(L1), here alpha_x is a list of model layers
def loss_L2L1(recon_x, x, alpha, beta, alpha_x, beta_y):
    tempN=x.shape[0]
    MSE = F.mse_loss(recon_x, x,reduction='sum')
    l2temp=0.0
    for temp in alpha_x:
        l2temp = l2temp+ temp.weight.norm(2)
    L2loss=alpha*l2temp
    L1loss=beta*F.l1_loss(beta_y,torch.zeros_like(beta_y),reduction='sum')
    return (MSE+L2loss+L1loss)/(tempN*10*2*56*56)

#loss with L2 and L1 regularizer, version2
#something like loss = mseloss+ alpha*alpha_x(L2)+beta*beta_y(L1), here alpha_x is a list of model layers
def loss_L2L1v2(recon_x, x, alpha, beta, alpha_x, beta_y):
    tempB, tempC, tempD, tempH, tempW =x.size()
    MSE = F.mse_loss(recon_x, x,reduction='sum')
    l2temp=0.0
    for temp in alpha_x:
        l2temp = l2temp+ temp.weight.norm(2)
    L2loss=alpha*l2temp
    B, C, D, H, W = beta_y.size() # Batch*channel*depth*height*width
    temp1=beta_y.view(B,C,-1)
    temp2=torch.norm(temp1,p=2,dim=2)
    temp3=torch.sum(torch.abs(temp2))
    L1loss=beta*temp3
    return (MSE+L2loss+L1loss)/(tempB* tempC* tempD* tempH* tempW)

#loss with L2 and L1 regularizer, for AE
#something like loss = mseloss+ alpha*alpha_x(L2)+beta*beta_y(L1), here alpha_x is a list of model layers
def loss_L2L1_FC(recon_x, x, alpha, beta, alpha_x, beta_y):
    tempB, tempC, tempH, tempW =x.size()
    MSE = F.mse_loss(recon_x, x,reduction='sum')
    l2temp=0.0
    for temp in alpha_x:
        l2temp = l2temp+ temp.weight.norm(2)
    L2loss=alpha*l2temp
    l1temp=0.0
    for temp in beta_y:
        l1temp = l1temp+ temp.norm(1)
    L1loss=beta*l1temp
    return (MSE+L2loss+L1loss)/(tempB* tempC* tempH* tempW)
def loss_L2L1_FC_ssim(recon_x, x, alpha, beta, alpha_x, beta_y):
    tempB, tempC, tempH, tempW =x.size()
    MSE = -pytorch_ssim.ssim(recon_x, x,window_size=3)
    l2temp=0.0
    for temp in alpha_x:
        l2temp = l2temp+ temp.weight.norm(2)
    L2loss=alpha*l2temp
    l1temp=0.0
    for temp in beta_y:
        l1temp = l1temp+ temp.norm(1)
    L1loss=beta*l1temp
    return MSE+(L2loss+L1loss)/(tempB* tempC* tempH* tempW)

#loss with L2 and L1 regularizer, for AE without fully connective layer
#something like loss = mseloss+ alpha*alpha_x(L2)+beta*beta_y(L1), here alpha_x is a list of model layers
#beta_y is encoded output
def loss_L2L1_NoFC(recon_x, x, alpha, beta, alpha_x, beta_y):
    tempB, tempC, tempH, tempW =x.size()
    MSE = F.mse_loss(recon_x, x,reduction='sum')
    l2temp=0.0
    for temp in alpha_x:
        l2temp = l2temp+ temp.weight.norm(2)
    L2loss=alpha*l2temp
    l1temp=0.0
    for temp in beta_y:
        l1temp = l1temp+ temp.norm(1)
    L1loss=beta*l1temp
    return (MSE+L2loss+L1loss)/(tempB* tempC* tempH* tempW)

class GaussianNoise(nn.Module):
    def __init__(self, sigma=0.1, is_relative_detach=True):
        super().__init__()
        self.sigma = sigma
        self.is_relative_detach = is_relative_detach
    def forward(self, x):
        if self.training and self.sigma != 0:
            sampled_noise = torch.randn(x.size(),requires_grad=False).to(device)* self.sigma
            x = x + x*sampled_noise
        return x 

#loss with L2 and L1 regularizer, for AE without fully connective layer
#something like loss = ssimloss+ alpha*alpha_x(L2)+beta*beta_y(L1), here alpha_x is a list of model layers
#beta_y is encoded output
def loss_L2L1_NoFC_ssim(recon_x, x, alpha, beta, alpha_x, beta_y):
    tempB, tempC, tempH, tempW =x.size()
    MSE = -pytorch_ssim.ssim(recon_x, x,window_size=3)
    l2temp=0.0
    for temp in alpha_x:
        l2temp = l2temp+ temp.weight.norm(2)
    L2loss=alpha*l2temp
    l1temp=0.0
    for temp in beta_y:
        l1temp = l1temp+ temp.norm(1)
    L1loss=beta*l1temp
    return MSE+(L2loss+L1loss)/(tempB* tempC* tempH* tempW)

# %% [markdown]
# # <font color='red'> AE</font>
# ## spatial, mse loss

# %%
class Autoencoder18_FC(nn.Module):
    def __init__(self):
        super(Autoencoder18_FC, self).__init__()
        self.conv1 =nn.Conv2d(2,16,kernel_size=9,stride=1,padding=4) 
        self.dconv1=nn.ConvTranspose2d(16,2,kernel_size=9,stride=1,padding=4) 
        self.fc1   =nn.Linear(16*28*28,16*28*28)
        self.dfc1  = nn.Linear(16*28*28,16*28*28)
        self.encoder = nn.Sequential(
            self.conv1, 
            nn.ReLU(),
            Flatten(),
            self.fc1,
            nn.ReLU(),
            GaussianNoise(sigma=1)
        )
        self.decoder = nn.Sequential(
            self.dfc1,
            nn.ReLU(),
            Unflatten(-1,16,28,28),
            self.dconv1, 
            nn.Tanh()
        )
    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return encoded, decoded

# %%
#function for training
def model_train(model,data,optimizer,device,EPOCH,loss_func,alpha=None,beta=None):
    print(datetime.datetime.now())
    model=model.to(device)
    model=model.train()
    loss=0.0
    train_loss=0.0
    for epoch in range(EPOCH):
        for step, x in enumerate(data):
            x=x/255.0
            x[:,0,:,:]=x[:,0,:,:]-sky_bg_mean_f[0]
            x[:,1,:,:]=x[:,1,:,:]-sky_bg_mean_f[1]
            b_x = torch.from_numpy(x).float().to(device) 
            b_y = torch.from_numpy(x).float().to(device) 
            if 'dn' in model.__class__.__name__:
                b_x=b_x+0.05*torch.randn(b_x.size()).to(device)
                b_x=torch.clamp(b_x,min=-1.0,max=1.0)
            if 'VariationalAE' in model.__class__.__name__:
                encoded, mu, logvar, decoded = model(b_x)
                loss = loss_func(decoded, b_y, mu, logvar,beta)
            if 'L2L1' in model.__class__.__name__:
                encoded, decoded = model(b_x)
                loss=loss_func(decoded, b_y,alpha,beta,[model.conv1,model.dconv1],\
                               encoded)
            if 'FC' in model.__class__.__name__:
                encoded, decoded = model(b_x)
                loss=loss_func(decoded, b_y,alpha,beta,[model.conv1,model.dconv1],\
                               encoded)
            if epoch==EPOCH-1:
                train_loss=train_loss+loss.cpu().data.numpy()
            optimizer.zero_grad()               # clear gradients for this training step
            loss.backward()                     # backpropagation, compute gradients
            optimizer.step()                    # apply gradients
            if step % 100 == 0:
                print('Model: ',model.__class__.__name__,'|Epoch: ', epoch,\
                      '| train loss: %.4f' % loss.cpu().data.numpy())
    print ('finish training!')
    print(datetime.datetime.now())
    train_loss=train_loss/len(data)
    print ('Model: ',model.__class__.__name__,'|train loss: %.4f' % train_loss)
    return train_loss

# %%
#use the trained model to test the validation loss
#val_eg: the example used to show results
def model_val(model,data,val_eg,device,loss_func):
    model=model.to(device)
    model=model.eval()
    data=data/255.0
    x=data
    x[:,0,:,:]=x[:,0,:,:]-sky_bg_mean_f[0]
    x[:,1,:,:]=x[:,1,:,:]-sky_bg_mean_f[1]
    b_x = torch.from_numpy(x).float().to(device) 
    b_y = torch.from_numpy(x).float().to(device)
    if 'dn' in model.__class__.__name__:
        b_x=b_x+0.05*torch.randn(b_x.size()).to(device)
        b_x=torch.clamp(b_x,min=-1.0,max=1.0)
    if 'VariationalAE' in model.__class__.__name__:
        encoded, mu, logvar, decoded = model(b_x)
        val_loss = loss_func(decoded, b_y, mu, logvar,0)
    else:
        encoded,decoded = model(b_x)
        val_loss=loss_func(decoded, b_y)
    print ('Model: ',model.__class__.__name__,'|validation loss: %.4f' % val_loss.cpu().data.numpy())
    x[:,0,:,:]=x[:,0,:,:]+sky_bg_mean_f[0]
    x[:,1,:,:]=x[:,1,:,:]+sky_bg_mean_f[1]
    fig, axes = plt.subplots(nrows=2, ncols=10,figsize=(15,3))
    for jj in range(10):
        temp=np.zeros((28,28,3),np.uint8)
        temp[...,1:]=np.uint8(np.transpose(x[val_eg+jj],(1,2,0))[...,::-1]*255)
        axes[0,jj].imshow(img_real2view(temp))
        axes[0,jj].grid(False)
        if jj==0:
            axes[0,jj].set_title('Target')
    decoded_np=decoded.cpu().data.numpy()
    decoded_np[:,0,:,:]=decoded_np[:,0,:,:]+sky_bg_mean_f[0]
    decoded_np[:,1,:,:]=decoded_np[:,1,:,:]+sky_bg_mean_f[1]
    decoded_np= np.clip(decoded_np, 0.0, 1.0)
    for jj in range(10):
        temp=np.zeros((28,28,3),np.uint8)
        temp[...,1:]=np.uint8(np.transpose(decoded_np[val_eg+jj],(1,2,0))[...,::-1]*255)
        axes[1,jj].imshow(img_real2view(temp))
        axes[1,jj].grid(False)
        if jj==0:
            axes[1,jj].set_title('Predict')
    return val_loss.cpu().data.numpy()

# %%
#function: visualize conv0 weights
def Vis_conv3d_0(conv3d_0,temptitle):
    #UV channel
    (outd,ind,_,_)=conv3d_0.shape
    '''
    fig, axes = plt.subplots(nrows=int(outd/8), ncols=8,figsize=(10, int(outd/8)))
    for ii in range(int(outd/8)):
        for jj in range(8):
            #temp=np.max([np.abs(np.min(conv3d_0[ii*8+jj,0,...])),np.abs(np.max(conv3d_0[ii*8+jj,0,...]))])
            #weight_min=-temp
            #weight_max=temp
            axes[ii,jj].imshow(conv3d_0[ii*8+jj,0,...],vmin=weight_min,vmax=weight_max,cmap='bwr')
            axes[ii,jj].set_xticks([]),axes[ii,jj].set_yticks([])
            if ii==0 and jj==0:
                axes[ii,jj].set_title(str(temptitle))
    #G channel
    weight_min=np.min(conv3d_0) #np.min(conv3d_0[:,1,...])
    weight_max=np.max(conv3d_0) #np.max(conv3d_0[:,1,...])
    if weight_max>(weight_min*(-1.0)):
        weight_min=weight_max*(-1.0)
    if weight_max<(weight_min*(-1.0)):
        weight_max=weight_min*(-1.0)
    fig, axes = plt.subplots(nrows=int(outd/8), ncols=8,figsize=(10, int(outd/8)))
    for ii in range(int(outd/8)):
        for jj in range(8):
            #temp=np.max([np.abs(np.min(conv3d_0[ii*8+jj,1,...])),np.abs(np.max(conv3d_0[ii*8+jj,1,...]))])
            #weight_min=-temp
            #weight_max=temp
            axes[ii,jj].imshow(conv3d_0[ii*8+jj,1,...],vmin=weight_min,vmax=weight_max,cmap='bwr')
            axes[ii,jj].set_xticks([]),axes[ii,jj].set_yticks([])
    '''
    fig, axes = plt.subplots(nrows=2, ncols=outd,figsize=(outd, 2))
    for jj in range(outd):
        weight_max=np.max(np.abs(conv3d_0[jj,...]))
        axes[0,jj].imshow(conv3d_0[jj,0,...],vmin=-weight_max,vmax=weight_max,cmap='bwr')#UV
        axes[0,jj].set_xticks([]),axes[0,jj].set_yticks([])
        if jj==0:
            axes[0,jj].set_title(str(temptitle))
        axes[1,jj].imshow(conv3d_0[jj,1,...],vmin=-weight_max,vmax=weight_max,cmap='bwr')#G
        axes[1,jj].set_xticks([]),axes[1,jj].set_yticks([])
    #plt.tight_layout()
    #fig.subplots_adjust(right=0.8)
    #cbar_ax = fig.add_axes([0.85, 0.15, 0.05, 0.5])
    #fig.colorbar(im, cax=cbar_ax)
    #fig.savefig('./out/ae3D_4_wL2_initDefault_sky_conv3d_0.svg')

# %%
#using pearson correlation as metric
def model_test(model,data,test_eg,device,loss_func):
    model=model.to(device)
    model=model.eval()
    data=data/255.0
    x=data
    x[:,0,:,:]=x[:,0,:,:]-sky_bg_mean_f[0]
    x[:,1,:,:]=x[:,1,:,:]-sky_bg_mean_f[1]
    b_x = torch.from_numpy(x).float().to(device) 
    b_y = torch.from_numpy(x).float().to(device)
    encoded,decoded = model(b_x)
    test_loss=loss_func(decoded, b_y)
    print ('Model: ',model.__class__.__name__,'|test loss: %.4f' % test_loss.cpu().data.numpy())
    x[:,0,:,:]=x[:,0,:,:]+sky_bg_mean_f[0]
    x[:,1,:,:]=x[:,1,:,:]+sky_bg_mean_f[1]
    fig, axes = plt.subplots(nrows=2, ncols=10,figsize=(15,3))
    for jj in range(10):
        temp=np.zeros((28,28,3),np.uint8)
        temp[...,1:]=np.uint8(np.transpose(x[test_eg+jj],(1,2,0))[...,::-1]*255)
        axes[0,jj].imshow(img_real2view(temp))
        axes[0,jj].grid(False)
        if jj==0:
            axes[0,jj].set_title('Target')
    decoded_np=decoded.cpu().data.numpy()
    decoded_np[:,0,:,:]=decoded_np[:,0,:,:]+sky_bg_mean_f[0]
    decoded_np[:,1,:,:]=decoded_np[:,1,:,:]+sky_bg_mean_f[1]
    decoded_np= np.clip(decoded_np, 0.0, 1.0)
    for jj in range(10):
        temp=np.zeros((28,28,3),np.uint8)
        temp[...,1:]=np.transpose(decoded_np[test_eg+jj],(1,2,0))[...,::-1]
        axes[1,ii].imshow(img_real2view(temp))
        axes[1,jj].grid(False)
        if jj==0:
            axes[1,jj].set_title('Predict')
    return test_loss.cpu().data.numpy()

# %%
#mse loss
EPOCH = 100
alphas=[ 0,   1e2,  1e3,   1e4,  1e5] 
betas =[ 0, 1/256, 1/64,  1/16,  1/4] 
modeltrainloss=[]
modelvalloss=[]
for ii in range(len(alphas)):
    for jj in range(len(betas)):
        modelname=str(ii*len(betas)+jj+1)
        torch.manual_seed(1)    
        torch.cuda.manual_seed(1)
        tempmodel = Autoencoder18_FC()
        optimizer = torch.optim.Adam(tempmodel.parameters(), lr=LR,weight_decay=0.0)
        temp=model_train(tempmodel,train_loader,optimizer,device,EPOCH,loss_L2L1_FC,alpha=alphas[ii],beta=betas[jj])
        modeltrainloss.append(temp)
        torch.save(tempmodel.state_dict(), 'out/ae_18_FC_lower_thresh_mse_'+modelname+'.pth')
        temp=model_val(tempmodel,val_loader,20,device,loss_mse)
        modelvalloss.append(temp)
        del tempmodel
        torch.cuda.empty_cache()
# Out:
# 2020-05-13 08:51:27.062637
# Model:  Autoencoder18_FC |Epoch:  0 | train loss: 0.0309
# Model:  Autoencoder18_FC |Epoch:  1 | train loss: 0.0041
# Model:  Autoencoder18_FC |Epoch:  2 | train loss: 0.0028
# Model:  Autoencoder18_FC |Epoch:  3 | train loss: 0.0023
# Model:  Autoencoder18_FC |Epoch:  4 | train loss: 0.0021
# Model:  Autoencoder18_FC |Epoch:  5 | train loss: 0.0019
# Model:  Autoencoder18_FC |Epoch:  6 | train loss: 0.0018
# Model:  Autoencoder18_FC |Epoch:  7 | train loss: 0.0017
# Model:  Autoencoder18_FC |Epoch:  8 | train loss: 0.0017
# Model:  Autoencoder18_FC |Epoch:  9 | train loss: 0.0016
# Model:  Autoencoder18_FC |Epoch:  10 | train loss: 0.0015
# Model:  Autoencoder18_FC |Epoch:  11 | train loss: 0.0014
# Model:  Autoencoder18_FC |Epoch:  12 | train loss: 0.0015
# Model:  Autoencoder18_FC |Epoch:  13 | train loss: 0.0013
# Model:  Autoencoder18_FC |Epoch:  14 | train loss: 0.0013
# Model:  Autoencoder18_FC |Epoch:  15 | train loss: 0.0013
# Model:  Autoencoder18_FC |Epoch:  16 | train loss: 0.0015
# Model:  Autoencoder18_FC |Epoch:  17 | train loss: 0.0013
# Model:  Autoencoder18_FC |Epoch:  18 | train loss: 0.0012
# Model:  Autoencoder18_FC |Epoch:  19 | train loss: 0.0012
# Model:  Autoencoder18_FC |Epoch:  20 | train loss: 0.0012
# Model:  Autoencoder18_FC |Epoch:  21 | train loss: 0.0012
# Model:  Autoencoder18_FC |Epoch:  22 | train loss: 0.0011
# Model:  Autoencoder18_FC |Epoch:  23 | train loss: 0.0013
# Model:  Autoencoder18_FC |Epoch:  24 | train loss: 0.0012
# Model:  Autoencoder18_FC |Epoch:  25 | train loss: 0.0011
# Model:  Autoencoder18_FC |Epoch:  26 | train loss: 0.0011
# Model:  Autoencoder18_FC |Epoch:  27 | train loss: 0.0011
# Model:  Autoencoder18_FC |Epoch:  28 | train loss: 0.0011
# Model:  Autoencoder18_FC |Epoch:  29 | train loss: 0.0011
# Model:  Autoencoder18_FC |Epoch:  30 | train loss: 0.0010
# Model:  Autoencoder18_FC |Epoch:  31 | train loss: 0.0013
# Model:  Autoencoder18_FC |Epoch:  32 | train loss: 0.0011
# Model:  Autoencoder18_FC |Epoch:  33 | train loss: 0.0010
# Model:  Autoencoder18_FC |Epoch:  34 | train loss: 0.0011
# Model:  Autoencoder18_FC |Epoch:  35 | train loss: 0.0011
# Model:  Autoencoder18_FC |Epoch:  36 | train loss: 0.0012
# Model:  Autoencoder18_FC |Epoch:  37 | train loss: 0.0011
# Model:  Autoencoder18_FC |Epoch:  38 | train loss: 0.0010
# Model:  Autoencoder18_FC |Epoch:  39 | train loss: 0.0009
# Model:  Autoencoder18_FC |Epoch:  40 | train loss: 0.0010
# Model:  Autoencoder18_FC |Epoch:  41 | train loss: 0.0010
# Model:  Autoencoder18_FC |Epoch:  42 | train loss: 0.0011
# Model:  Autoencoder18_FC |Epoch:  43 | train loss: 0.0012
# Model:  Autoencoder18_FC |Epoch:  44 | train loss: 0.0011
# Model:  Autoencoder18_FC |Epoch:  45 | train loss: 0.0010
# Model:  Autoencoder18_FC |Epoch:  46 | train loss: 0.0009
# Model:  Autoencoder18_FC |Epoch:  47 | train loss: 0.0009
# Model:  Autoencoder18_FC |Epoch:  48 | train loss: 0.0009
# Model:  Autoencoder18_FC |Epoch:  49 | train loss: 0.0009
# Model:  Autoencoder18_FC |Epoch:  50 | train loss: 0.0009
# Model:  Autoencoder18_FC |Epoch:  51 | train loss: 0.0009
# Model:  Autoencoder18_FC |Epoch:  52 | train loss: 0.0010
# Model:  Autoencoder18_FC |Epoch:  53 | train loss: 0.0010
# Model:  Autoencoder18_FC |Epoch:  54 | train loss: 0.0009
# Model:  Autoencoder18_FC |Epoch:  55 | train loss: 0.0009
# Model:  Autoencoder18_FC |Epoch:  56 | train loss: 0.0012
# Model:  Autoencoder18_FC |Epoch:  57 | train loss: 0.0014
# Model:  Autoencoder18_FC |Epoch:  58 | train loss: 0.0014
# Model:  Autoencoder18_FC |Epoch:  59 | train loss: 0.0011
# Model:  Autoencoder18_FC |Epoch:  60 | train loss: 0.0009
# Model:  Autoencoder18_FC |Epoch:  61 | train loss: 0.0010
# Model:  Autoencoder18_FC |Epoch:  62 | train loss: 0.0013
# Model:  Autoencoder18_FC |Epoch:  63 | train loss: 0.0012
# Model:  Autoencoder18_FC |Epoch:  64 | train loss: 0.0010
# Model:  Autoencoder18_FC |Epoch:  65 | train loss: 0.0009
# Model:  Autoencoder18_FC |Epoch:  66 | train loss: 0.0008
# Model:  Autoencoder18_FC |Epoch:  67 | train loss: 0.0008
# Model:  Autoencoder18_FC |Epoch:  68 | train loss: 0.0008
# Model:  Autoencoder18_FC |Epoch:  69 | train loss: 0.0008
# Model:  Autoencoder18_FC |Epoch:  70 | train loss: 0.0008
# Model:  Autoencoder18_FC |Epoch:  71 | train loss: 0.0009
# Model:  Autoencoder18_FC |Epoch:  72 | train loss: 0.0009
# Model:  Autoencoder18_FC |Epoch:  73 | train loss: 0.0008
# Model:  Autoencoder18_FC |Epoch:  74 | train loss: 0.0011
# Model:  Autoencoder18_FC |Epoch:  75 | train loss: 0.0010
# Model:  Autoencoder18_FC |Epoch:  76 | train loss: 0.0009
# Model:  Autoencoder18_FC |Epoch:  77 | train loss: 0.0009
# Model:  Autoencoder18_FC |Epoch:  78 | train loss: 0.0009
# Model:  Autoencoder18_FC |Epoch:  79 | train loss: 0.0010
# Model:  Autoencoder18_FC |Epoch:  80 | train loss: 0.0011
# Model:  Autoencoder18_FC |Epoch:  81 | train loss: 0.0009
# Model:  Autoencoder18_FC |Epoch:  82 | train loss: 0.0008
# Model:  Autoencoder18_FC |Epoch:  83 | train loss: 0.0008
# Model:  Autoencoder18_FC |Epoch:  84 | train loss: 0.0008
# Model:  Autoencoder18_FC |Epoch:  85 | train loss: 0.0008
# Model:  Autoencoder18_FC |Epoch:  86 | train loss: 0.0009
# Model:  Autoencoder18_FC |Epoch:  87 | train loss: 0.0009
# Model:  Autoencoder18_FC |Epoch:  88 | train loss: 0.0009
# Model:  Autoencoder18_FC |Epoch:  89 | train loss: 0.0009
# Model:  Autoencoder18_FC |Epoch:  90 | train loss: 0.0008
# Model:  Autoencoder18_FC |Epoch:  91 | train loss: 0.0007
# Model:  Autoencoder18_FC |Epoch:  92 | train loss: 0.0008
# Model:  Autoencoder18_FC |Epoch:  93 | train loss: 0.0008
# Model:  Autoencoder18_FC |Epoch:  94 | train loss: 0.0009
# Model:  Autoencoder18_FC |Epoch:  95 | train loss: 0.0010
# Model:  Autoencoder18_FC |Epoch:  96 | train loss: 0.0009
# Model:  Autoencoder18_FC |Epoch:  97 | train loss: 0.0009
# Model:  Autoencoder18_FC |Epoch:  98 | train loss: 0.0009
# Model:  Autoencoder18_FC |Epoch:  99 | train loss: 0.0012
# finish training!
# 2020-05-13 09:07:51.072526
# Model:  Autoencoder18_FC |train loss: 0.0010
# Model:  Autoencoder18_FC |validation loss: 0.0031
# 2020-05-13 09:07:55.608625
# Model:  Autoencoder18_FC |Epoch:  0 | train loss: 0.0314
# Model:  Autoencoder18_FC |Epoch:  1 | train loss: 0.0046
# Model:  Autoencoder18_FC |Epoch:  2 | train loss: 0.0032
# Model:  Autoencoder18_FC |Epoch:  3 | train loss: 0.0027
# Model:  Autoencoder18_FC |Epoch:  4 | train loss: 0.0024
# Model:  Autoencoder18_FC |Epoch:  5 | train loss: 0.0025
# Model:  Autoencoder18_FC |Epoch:  6 | train loss: 0.0024
# Model:  Autoencoder18_FC |Epoch:  7 | train loss: 0.0020
# Model:  Autoencoder18_FC |Epoch:  8 | train loss: 0.0019
# Model:  Autoencoder18_FC |Epoch:  9 | train loss: 0.0019
# Model:  Autoencoder18_FC |Epoch:  10 | train loss: 0.0018
# Model:  Autoencoder18_FC |Epoch:  11 | train loss: 0.0019
# Model:  Autoencoder18_FC |Epoch:  12 | train loss: 0.0017
# Model:  Autoencoder18_FC |Epoch:  13 | train loss: 0.0020
# Model:  Autoencoder18_FC |Epoch:  14 | train loss: 0.0018
# Model:  Autoencoder18_FC |Epoch:  15 | train loss: 0.0018
# Model:  Autoencoder18_FC |Epoch:  16 | train loss: 0.0016
# Model:  Autoencoder18_FC |Epoch:  17 | train loss: 0.0015
# Model:  Autoencoder18_FC |Epoch:  18 | train loss: 0.0015
# Model:  Autoencoder18_FC |Epoch:  19 | train loss: 0.0016
# Model:  Autoencoder18_FC |Epoch:  20 | train loss: 0.0015
# Model:  Autoencoder18_FC |Epoch:  21 | train loss: 0.0014
# Model:  Autoencoder18_FC |Epoch:  22 | train loss: 0.0015
# Model:  Autoencoder18_FC |Epoch:  23 | train loss: 0.0014
# Model:  Autoencoder18_FC |Epoch:  24 | train loss: 0.0015
# Model:  Autoencoder18_FC |Epoch:  25 | train loss: 0.0016
# Model:  Autoencoder18_FC |Epoch:  26 | train loss: 0.0015
# Model:  Autoencoder18_FC |Epoch:  27 | train loss: 0.0015
# Model:  Autoencoder18_FC |Epoch:  28 | train loss: 0.0015
# Model:  Autoencoder18_FC |Epoch:  29 | train loss: 0.0017
# Model:  Autoencoder18_FC |Epoch:  30 | train loss: 0.0016
# Model:  Autoencoder18_FC |Epoch:  31 | train loss: 0.0014
# Model:  Autoencoder18_FC |Epoch:  32 | train loss: 0.0013
# Model:  Autoencoder18_FC |Epoch:  33 | train loss: 0.0015
# Model:  Autoencoder18_FC |Epoch:  34 | train loss: 0.0016
# Model:  Autoencoder18_FC |Epoch:  35 | train loss: 0.0013
# Model:  Autoencoder18_FC |Epoch:  36 | train loss: 0.0012
# Model:  Autoencoder18_FC |Epoch:  37 | train loss: 0.0013
# Model:  Autoencoder18_FC |Epoch:  38 | train loss: 0.0012
# Model:  Autoencoder18_FC |Epoch:  39 | train loss: 0.0012
# Model:  Autoencoder18_FC |Epoch:  40 | train loss: 0.0012
# Model:  Autoencoder18_FC |Epoch:  41 | train loss: 0.0012
# Model:  Autoencoder18_FC |Epoch:  42 | train loss: 0.0012
# Model:  Autoencoder18_FC |Epoch:  43 | train loss: 0.0012
# Model:  Autoencoder18_FC |Epoch:  44 | train loss: 0.0015
# Model:  Autoencoder18_FC |Epoch:  45 | train loss: 0.0018
# Model:  Autoencoder18_FC |Epoch:  46 | train loss: 0.0016
# Model:  Autoencoder18_FC |Epoch:  47 | train loss: 0.0013
# Model:  Autoencoder18_FC |Epoch:  48 | train loss: 0.0013
# Model:  Autoencoder18_FC |Epoch:  49 | train loss: 0.0014
# Model:  Autoencoder18_FC |Epoch:  50 | train loss: 0.0013
# Model:  Autoencoder18_FC |Epoch:  51 | train loss: 0.0012
# Model:  Autoencoder18_FC |Epoch:  52 | train loss: 0.0012
# Model:  Autoencoder18_FC |Epoch:  53 | train loss: 0.0010
# Model:  Autoencoder18_FC |Epoch:  54 | train loss: 0.0011
# Model:  Autoencoder18_FC |Epoch:  55 | train loss: 0.0011
# Model:  Autoencoder18_FC |Epoch:  56 | train loss: 0.0012
# Model:  Autoencoder18_FC |Epoch:  57 | train loss: 0.0011
# Model:  Autoencoder18_FC |Epoch:  58 | train loss: 0.0011
# Model:  Autoencoder18_FC |Epoch:  59 | train loss: 0.0013
# Model:  Autoencoder18_FC |Epoch:  60 | train loss: 0.0012
# Model:  Autoencoder18_FC |Epoch:  61 | train loss: 0.0012
# Model:  Autoencoder18_FC |Epoch:  62 | train loss: 0.0012
# Model:  Autoencoder18_FC |Epoch:  63 | train loss: 0.0011
# Model:  Autoencoder18_FC |Epoch:  64 | train loss: 0.0012
# Model:  Autoencoder18_FC |Epoch:  65 | train loss: 0.0013
# Model:  Autoencoder18_FC |Epoch:  66 | train loss: 0.0012
# Model:  Autoencoder18_FC |Epoch:  67 | train loss: 0.0011
# Model:  Autoencoder18_FC |Epoch:  68 | train loss: 0.0010
# Model:  Autoencoder18_FC |Epoch:  69 | train loss: 0.0010
# Model:  Autoencoder18_FC |Epoch:  70 | train loss: 0.0010
# Model:  Autoencoder18_FC |Epoch:  71 | train loss: 0.0011
# Model:  Autoencoder18_FC |Epoch:  72 | train loss: 0.0011
# Model:  Autoencoder18_FC |Epoch:  73 | train loss: 0.0011
# Model:  Autoencoder18_FC |Epoch:  74 | train loss: 0.0010
# Model:  Autoencoder18_FC |Epoch:  75 | train loss: 0.0010
# Model:  Autoencoder18_FC |Epoch:  76 | train loss: 0.0010
# Model:  Autoencoder18_FC |Epoch:  77 | train loss: 0.0010
# Model:  Autoencoder18_FC |Epoch:  78 | train loss: 0.0010
# Model:  Autoencoder18_FC |Epoch:  79 | train loss: 0.0009
# Model:  Autoencoder18_FC |Epoch:  80 | train loss: 0.0010
# Model:  Autoencoder18_FC |Epoch:  81 | train loss: 0.0010
# Model:  Autoencoder18_FC |Epoch:  82 | train loss: 0.0011
# Model:  Autoencoder18_FC |Epoch:  83 | train loss: 0.0011
# Model:  Autoencoder18_FC |Epoch:  84 | train loss: 0.0014
# Model:  Autoencoder18_FC |Epoch:  85 | train loss: 0.0015
# Model:  Autoencoder18_FC |Epoch:  86 | train loss: 0.0014
# Model:  Autoencoder18_FC |Epoch:  87 | train loss: 0.0010
# Model:  Autoencoder18_FC |Epoch:  88 | train loss: 0.0010
# Model:  Autoencoder18_FC |Epoch:  89 | train loss: 0.0010
# Model:  Autoencoder18_FC |Epoch:  90 | train loss: 0.0010
# Model:  Autoencoder18_FC |Epoch:  91 | train loss: 0.0010
# Model:  Autoencoder18_FC |Epoch:  92 | train loss: 0.0011
# Model:  Autoencoder18_FC |Epoch:  93 | train loss: 0.0012
# Model:  Autoencoder18_FC |Epoch:  94 | train loss: 0.0016
# Model:  Autoencoder18_FC |Epoch:  95 | train loss: 0.0015
# Model:  Autoencoder18_FC |Epoch:  96 | train loss: 0.0011
# Model:  Autoencoder18_FC |Epoch:  97 | train loss: 0.0010
# Model:  Autoencoder18_FC |Epoch:  98 | train loss: 0.0009
# Model:  Autoencoder18_FC |Epoch:  99 | train loss: 0.0011
# finish training!
# 2020-05-13 09:24:21.659621
# Model:  Autoencoder18_FC |train loss: 0.0011
# Model:  Autoencoder18_FC |validation loss: 0.0027
# 2020-05-13 09:24:27.055388
# Model:  Autoencoder18_FC |Epoch:  0 | train loss: 0.0329
# Model:  Autoencoder18_FC |Epoch:  1 | train loss: 0.0056
# Model:  Autoencoder18_FC |Epoch:  2 | train loss: 0.0041
# Model:  Autoencoder18_FC |Epoch:  3 | train loss: 0.0035
# Model:  Autoencoder18_FC |Epoch:  4 | train loss: 0.0033
# Model:  Autoencoder18_FC |Epoch:  5 | train loss: 0.0030
# Model:  Autoencoder18_FC |Epoch:  6 | train loss: 0.0030
# Model:  Autoencoder18_FC |Epoch:  7 | train loss: 0.0029
# Model:  Autoencoder18_FC |Epoch:  8 | train loss: 0.0027
# Model:  Autoencoder18_FC |Epoch:  9 | train loss: 0.0026
# Model:  Autoencoder18_FC |Epoch:  10 | train loss: 0.0025
# Model:  Autoencoder18_FC |Epoch:  11 | train loss: 0.0026
# Model:  Autoencoder18_FC |Epoch:  12 | train loss: 0.0023
# Model:  Autoencoder18_FC |Epoch:  13 | train loss: 0.0022
# Model:  Autoencoder18_FC |Epoch:  14 | train loss: 0.0024
# Model:  Autoencoder18_FC |Epoch:  15 | train loss: 0.0025
# Model:  Autoencoder18_FC |Epoch:  16 | train loss: 0.0024
# Model:  Autoencoder18_FC |Epoch:  17 | train loss: 0.0023
# Model:  Autoencoder18_FC |Epoch:  18 | train loss: 0.0022
# Model:  Autoencoder18_FC |Epoch:  19 | train loss: 0.0020
# Model:  Autoencoder18_FC |Epoch:  20 | train loss: 0.0021
# Model:  Autoencoder18_FC |Epoch:  21 | train loss: 0.0022
# Model:  Autoencoder18_FC |Epoch:  22 | train loss: 0.0019
# Model:  Autoencoder18_FC |Epoch:  23 | train loss: 0.0019
# Model:  Autoencoder18_FC |Epoch:  24 | train loss: 0.0020
# Model:  Autoencoder18_FC |Epoch:  25 | train loss: 0.0020
# Model:  Autoencoder18_FC |Epoch:  26 | train loss: 0.0019
# Model:  Autoencoder18_FC |Epoch:  27 | train loss: 0.0019
# Model:  Autoencoder18_FC |Epoch:  28 | train loss: 0.0019
# Model:  Autoencoder18_FC |Epoch:  29 | train loss: 0.0020
# Model:  Autoencoder18_FC |Epoch:  30 | train loss: 0.0020
# Model:  Autoencoder18_FC |Epoch:  31 | train loss: 0.0018
# Model:  Autoencoder18_FC |Epoch:  32 | train loss: 0.0017
# Model:  Autoencoder18_FC |Epoch:  33 | train loss: 0.0018
# Model:  Autoencoder18_FC |Epoch:  34 | train loss: 0.0017
# Model:  Autoencoder18_FC |Epoch:  35 | train loss: 0.0018
# Model:  Autoencoder18_FC |Epoch:  36 | train loss: 0.0017
# Model:  Autoencoder18_FC |Epoch:  37 | train loss: 0.0017
# Model:  Autoencoder18_FC |Epoch:  38 | train loss: 0.0017
# Model:  Autoencoder18_FC |Epoch:  39 | train loss: 0.0018
# Model:  Autoencoder18_FC |Epoch:  40 | train loss: 0.0019
# Model:  Autoencoder18_FC |Epoch:  41 | train loss: 0.0018
# Model:  Autoencoder18_FC |Epoch:  42 | train loss: 0.0017
# Model:  Autoencoder18_FC |Epoch:  43 | train loss: 0.0016
# Model:  Autoencoder18_FC |Epoch:  44 | train loss: 0.0017
# Model:  Autoencoder18_FC |Epoch:  45 | train loss: 0.0019
# Model:  Autoencoder18_FC |Epoch:  46 | train loss: 0.0020
# Model:  Autoencoder18_FC |Epoch:  47 | train loss: 0.0018
# Model:  Autoencoder18_FC |Epoch:  48 | train loss: 0.0017
# Model:  Autoencoder18_FC |Epoch:  49 | train loss: 0.0016
# Model:  Autoencoder18_FC |Epoch:  50 | train loss: 0.0016
# Model:  Autoencoder18_FC |Epoch:  51 | train loss: 0.0017
# Model:  Autoencoder18_FC |Epoch:  52 | train loss: 0.0016
# Model:  Autoencoder18_FC |Epoch:  53 | train loss: 0.0015
# Model:  Autoencoder18_FC |Epoch:  54 | train loss: 0.0015
# Model:  Autoencoder18_FC |Epoch:  55 | train loss: 0.0015
# Model:  Autoencoder18_FC |Epoch:  56 | train loss: 0.0016
# Model:  Autoencoder18_FC |Epoch:  57 | train loss: 0.0015
# Model:  Autoencoder18_FC |Epoch:  58 | train loss: 0.0016
# Model:  Autoencoder18_FC |Epoch:  59 | train loss: 0.0015
# Model:  Autoencoder18_FC |Epoch:  60 | train loss: 0.0015
# Model:  Autoencoder18_FC |Epoch:  61 | train loss: 0.0016
# Model:  Autoencoder18_FC |Epoch:  62 | train loss: 0.0015
# Model:  Autoencoder18_FC |Epoch:  63 | train loss: 0.0015
# Model:  Autoencoder18_FC |Epoch:  64 | train loss: 0.0014
# Model:  Autoencoder18_FC |Epoch:  65 | train loss: 0.0014
# Model:  Autoencoder18_FC |Epoch:  66 | train loss: 0.0014
# Model:  Autoencoder18_FC |Epoch:  67 | train loss: 0.0013
# Model:  Autoencoder18_FC |Epoch:  68 | train loss: 0.0014
# Model:  Autoencoder18_FC |Epoch:  69 | train loss: 0.0014
# Model:  Autoencoder18_FC |Epoch:  70 | train loss: 0.0014
# Model:  Autoencoder18_FC |Epoch:  71 | train loss: 0.0014
# Model:  Autoencoder18_FC |Epoch:  72 | train loss: 0.0015
# Model:  Autoencoder18_FC |Epoch:  73 | train loss: 0.0014
# Model:  Autoencoder18_FC |Epoch:  74 | train loss: 0.0014
# Model:  Autoencoder18_FC |Epoch:  75 | train loss: 0.0014
# Model:  Autoencoder18_FC |Epoch:  76 | train loss: 0.0016
# Model:  Autoencoder18_FC |Epoch:  77 | train loss: 0.0019
# Model:  Autoencoder18_FC |Epoch:  78 | train loss: 0.0017
# Model:  Autoencoder18_FC |Epoch:  79 | train loss: 0.0016
# Model:  Autoencoder18_FC |Epoch:  80 | train loss: 0.0016
# Model:  Autoencoder18_FC |Epoch:  81 | train loss: 0.0017
# Model:  Autoencoder18_FC |Epoch:  82 | train loss: 0.0020
# Model:  Autoencoder18_FC |Epoch:  83 | train loss: 0.0017
# Model:  Autoencoder18_FC |Epoch:  84 | train loss: 0.0014
# Model:  Autoencoder18_FC |Epoch:  85 | train loss: 0.0013
# Model:  Autoencoder18_FC |Epoch:  86 | train loss: 0.0013
# Model:  Autoencoder18_FC |Epoch:  87 | train loss: 0.0012
# Model:  Autoencoder18_FC |Epoch:  88 | train loss: 0.0013
# Model:  Autoencoder18_FC |Epoch:  89 | train loss: 0.0014
# Model:  Autoencoder18_FC |Epoch:  90 | train loss: 0.0014
# Model:  Autoencoder18_FC |Epoch:  91 | train loss: 0.0013
# Model:  Autoencoder18_FC |Epoch:  92 | train loss: 0.0013
# Model:  Autoencoder18_FC |Epoch:  93 | train loss: 0.0013
# Model:  Autoencoder18_FC |Epoch:  94 | train loss: 0.0013
# Model:  Autoencoder18_FC |Epoch:  95 | train loss: 0.0013
# Model:  Autoencoder18_FC |Epoch:  96 | train loss: 0.0014
# Model:  Autoencoder18_FC |Epoch:  97 | train loss: 0.0014
# Model:  Autoencoder18_FC |Epoch:  98 | train loss: 0.0015
# Model:  Autoencoder18_FC |Epoch:  99 | train loss: 0.0016
# finish training!
# 2020-05-13 09:41:04.266535
# Model:  Autoencoder18_FC |train loss: 0.0015
# Model:  Autoencoder18_FC |validation loss: 0.0022
# 2020-05-13 09:41:09.231692
# Model:  Autoencoder18_FC |Epoch:  0 | train loss: 0.0387
# Model:  Autoencoder18_FC |Epoch:  1 | train loss: 0.0075
# Model:  Autoencoder18_FC |Epoch:  2 | train loss: 0.0060
# Model:  Autoencoder18_FC |Epoch:  3 | train loss: 0.0052
# Model:  Autoencoder18_FC |Epoch:  4 | train loss: 0.0050
# Model:  Autoencoder18_FC |Epoch:  5 | train loss: 0.0045
# Model:  Autoencoder18_FC |Epoch:  6 | train loss: 0.0044
# Model:  Autoencoder18_FC |Epoch:  7 | train loss: 0.0042
# Model:  Autoencoder18_FC |Epoch:  8 | train loss: 0.0040
# Model:  Autoencoder18_FC |Epoch:  9 | train loss: 0.0039
# Model:  Autoencoder18_FC |Epoch:  10 | train loss: 0.0039
# Model:  Autoencoder18_FC |Epoch:  11 | train loss: 0.0039
# Model:  Autoencoder18_FC |Epoch:  12 | train loss: 0.0038
# Model:  Autoencoder18_FC |Epoch:  13 | train loss: 0.0039
# Model:  Autoencoder18_FC |Epoch:  14 | train loss: 0.0035
# Model:  Autoencoder18_FC |Epoch:  15 | train loss: 0.0035
# Model:  Autoencoder18_FC |Epoch:  16 | train loss: 0.0034
# Model:  Autoencoder18_FC |Epoch:  17 | train loss: 0.0033
# Model:  Autoencoder18_FC |Epoch:  18 | train loss: 0.0034
# Model:  Autoencoder18_FC |Epoch:  19 | train loss: 0.0033
# Model:  Autoencoder18_FC |Epoch:  20 | train loss: 0.0034
# Model:  Autoencoder18_FC |Epoch:  21 | train loss: 0.0033
# Model:  Autoencoder18_FC |Epoch:  22 | train loss: 0.0035
# Model:  Autoencoder18_FC |Epoch:  23 | train loss: 0.0033
# Model:  Autoencoder18_FC |Epoch:  24 | train loss: 0.0032
# Model:  Autoencoder18_FC |Epoch:  25 | train loss: 0.0032
# Model:  Autoencoder18_FC |Epoch:  26 | train loss: 0.0031
# Model:  Autoencoder18_FC |Epoch:  27 | train loss: 0.0031
# Model:  Autoencoder18_FC |Epoch:  28 | train loss: 0.0031
# Model:  Autoencoder18_FC |Epoch:  29 | train loss: 0.0029
# Model:  Autoencoder18_FC |Epoch:  30 | train loss: 0.0032
# Model:  Autoencoder18_FC |Epoch:  31 | train loss: 0.0030
# Model:  Autoencoder18_FC |Epoch:  32 | train loss: 0.0030
# Model:  Autoencoder18_FC |Epoch:  33 | train loss: 0.0030
# Model:  Autoencoder18_FC |Epoch:  34 | train loss: 0.0030
# Model:  Autoencoder18_FC |Epoch:  35 | train loss: 0.0029
# Model:  Autoencoder18_FC |Epoch:  36 | train loss: 0.0030
# Model:  Autoencoder18_FC |Epoch:  37 | train loss: 0.0029
# Model:  Autoencoder18_FC |Epoch:  38 | train loss: 0.0028
# Model:  Autoencoder18_FC |Epoch:  39 | train loss: 0.0028
# Model:  Autoencoder18_FC |Epoch:  40 | train loss: 0.0031
# Model:  Autoencoder18_FC |Epoch:  41 | train loss: 0.0033
# Model:  Autoencoder18_FC |Epoch:  42 | train loss: 0.0032
# Model:  Autoencoder18_FC |Epoch:  43 | train loss: 0.0029
# Model:  Autoencoder18_FC |Epoch:  44 | train loss: 0.0027
# Model:  Autoencoder18_FC |Epoch:  45 | train loss: 0.0031
# Model:  Autoencoder18_FC |Epoch:  46 | train loss: 0.0031
# Model:  Autoencoder18_FC |Epoch:  47 | train loss: 0.0030
# Model:  Autoencoder18_FC |Epoch:  48 | train loss: 0.0028
# Model:  Autoencoder18_FC |Epoch:  49 | train loss: 0.0027
# Model:  Autoencoder18_FC |Epoch:  50 | train loss: 0.0026
# Model:  Autoencoder18_FC |Epoch:  51 | train loss: 0.0027
# Model:  Autoencoder18_FC |Epoch:  52 | train loss: 0.0028
# Model:  Autoencoder18_FC |Epoch:  53 | train loss: 0.0027
# Model:  Autoencoder18_FC |Epoch:  54 | train loss: 0.0028
# Model:  Autoencoder18_FC |Epoch:  55 | train loss: 0.0028
# Model:  Autoencoder18_FC |Epoch:  56 | train loss: 0.0029
# Model:  Autoencoder18_FC |Epoch:  57 | train loss: 0.0029
# Model:  Autoencoder18_FC |Epoch:  58 | train loss: 0.0028
# Model:  Autoencoder18_FC |Epoch:  59 | train loss: 0.0028
# Model:  Autoencoder18_FC |Epoch:  60 | train loss: 0.0028
# Model:  Autoencoder18_FC |Epoch:  61 | train loss: 0.0031
# Model:  Autoencoder18_FC |Epoch:  62 | train loss: 0.0030
# Model:  Autoencoder18_FC |Epoch:  63 | train loss: 0.0028
# Model:  Autoencoder18_FC |Epoch:  64 | train loss: 0.0026
# Model:  Autoencoder18_FC |Epoch:  65 | train loss: 0.0026
# Model:  Autoencoder18_FC |Epoch:  66 | train loss: 0.0026
# Model:  Autoencoder18_FC |Epoch:  67 | train loss: 0.0025
# Model:  Autoencoder18_FC |Epoch:  68 | train loss: 0.0025
# Model:  Autoencoder18_FC |Epoch:  69 | train loss: 0.0024
# Model:  Autoencoder18_FC |Epoch:  70 | train loss: 0.0025
# Model:  Autoencoder18_FC |Epoch:  71 | train loss: 0.0024
# Model:  Autoencoder18_FC |Epoch:  72 | train loss: 0.0024
# Model:  Autoencoder18_FC |Epoch:  73 | train loss: 0.0025
# Model:  Autoencoder18_FC |Epoch:  74 | train loss: 0.0024
# Model:  Autoencoder18_FC |Epoch:  75 | train loss: 0.0025
# Model:  Autoencoder18_FC |Epoch:  76 | train loss: 0.0025
# Model:  Autoencoder18_FC |Epoch:  77 | train loss: 0.0024
# Model:  Autoencoder18_FC |Epoch:  78 | train loss: 0.0023
# Model:  Autoencoder18_FC |Epoch:  79 | train loss: 0.0024
# Model:  Autoencoder18_FC |Epoch:  80 | train loss: 0.0023
# Model:  Autoencoder18_FC |Epoch:  81 | train loss: 0.0024
# Model:  Autoencoder18_FC |Epoch:  82 | train loss: 0.0023
# Model:  Autoencoder18_FC |Epoch:  83 | train loss: 0.0024
# Model:  Autoencoder18_FC |Epoch:  84 | train loss: 0.0024
# Model:  Autoencoder18_FC |Epoch:  85 | train loss: 0.0023
# Model:  Autoencoder18_FC |Epoch:  86 | train loss: 0.0023
# Model:  Autoencoder18_FC |Epoch:  87 | train loss: 0.0023
# Model:  Autoencoder18_FC |Epoch:  88 | train loss: 0.0023
# Model:  Autoencoder18_FC |Epoch:  89 | train loss: 0.0023
# Model:  Autoencoder18_FC |Epoch:  90 | train loss: 0.0023
# Model:  Autoencoder18_FC |Epoch:  91 | train loss: 0.0024
# Model:  Autoencoder18_FC |Epoch:  92 | train loss: 0.0023
# Model:  Autoencoder18_FC |Epoch:  93 | train loss: 0.0024
# Model:  Autoencoder18_FC |Epoch:  94 | train loss: 0.0024
# Model:  Autoencoder18_FC |Epoch:  95 | train loss: 0.0022
# Model:  Autoencoder18_FC |Epoch:  96 | train loss: 0.0022
# Model:  Autoencoder18_FC |Epoch:  97 | train loss: 0.0023
# Model:  Autoencoder18_FC |Epoch:  98 | train loss: 0.0023
# Model:  Autoencoder18_FC |Epoch:  99 | train loss: 0.0023
# finish training!
# 2020-05-13 09:58:05.722457
# Model:  Autoencoder18_FC |train loss: 0.0024
# Model:  Autoencoder18_FC |validation loss: 0.0030
# 2020-05-13 09:58:10.586780
# Model:  Autoencoder18_FC |Epoch:  0 | train loss: 0.0618
# Model:  Autoencoder18_FC |Epoch:  1 | train loss: 0.0154
# Model:  Autoencoder18_FC |Epoch:  2 | train loss: 0.0133
# Model:  Autoencoder18_FC |Epoch:  3 | train loss: 0.0132
# Model:  Autoencoder18_FC |Epoch:  4 | train loss: 0.0133
# Model:  Autoencoder18_FC |Epoch:  5 | train loss: 0.0121
# Model:  Autoencoder18_FC |Epoch:  6 | train loss: 0.0124
# Model:  Autoencoder18_FC |Epoch:  7 | train loss: 0.0120
# Model:  Autoencoder18_FC |Epoch:  8 | train loss: 0.0121
# Model:  Autoencoder18_FC |Epoch:  9 | train loss: 0.0120
# Model:  Autoencoder18_FC |Epoch:  10 | train loss: 0.0116
# Model:  Autoencoder18_FC |Epoch:  11 | train loss: 0.0120
# Model:  Autoencoder18_FC |Epoch:  12 | train loss: 0.0120
# Model:  Autoencoder18_FC |Epoch:  13 | train loss: 0.0114
# Model:  Autoencoder18_FC |Epoch:  14 | train loss: 0.0126
# Model:  Autoencoder18_FC |Epoch:  15 | train loss: 0.0114
# Model:  Autoencoder18_FC |Epoch:  16 | train loss: 0.0113
# Model:  Autoencoder18_FC |Epoch:  17 | train loss: 0.0111
# Model:  Autoencoder18_FC |Epoch:  18 | train loss: 0.0112
# Model:  Autoencoder18_FC |Epoch:  19 | train loss: 0.0111
# Model:  Autoencoder18_FC |Epoch:  20 | train loss: 0.0112
# Model:  Autoencoder18_FC |Epoch:  21 | train loss: 0.0111
# Model:  Autoencoder18_FC |Epoch:  22 | train loss: 0.0110
# Model:  Autoencoder18_FC |Epoch:  23 | train loss: 0.0105
# Model:  Autoencoder18_FC |Epoch:  24 | train loss: 0.0106
# Model:  Autoencoder18_FC |Epoch:  25 | train loss: 0.0107
# Model:  Autoencoder18_FC |Epoch:  26 | train loss: 0.0109
# Model:  Autoencoder18_FC |Epoch:  27 | train loss: 0.0115
# Model:  Autoencoder18_FC |Epoch:  28 | train loss: 0.0104
# Model:  Autoencoder18_FC |Epoch:  29 | train loss: 0.0121
# Model:  Autoencoder18_FC |Epoch:  30 | train loss: 0.0108
# Model:  Autoencoder18_FC |Epoch:  31 | train loss: 0.0102
# Model:  Autoencoder18_FC |Epoch:  32 | train loss: 0.0101
# Model:  Autoencoder18_FC |Epoch:  33 | train loss: 0.0109
# Model:  Autoencoder18_FC |Epoch:  34 | train loss: 0.0105
# Model:  Autoencoder18_FC |Epoch:  35 | train loss: 0.0113
# Model:  Autoencoder18_FC |Epoch:  36 | train loss: 0.0101
# Model:  Autoencoder18_FC |Epoch:  37 | train loss: 0.0099
# Model:  Autoencoder18_FC |Epoch:  38 | train loss: 0.0103
# Model:  Autoencoder18_FC |Epoch:  39 | train loss: 0.0103
# Model:  Autoencoder18_FC |Epoch:  40 | train loss: 0.0103
# Model:  Autoencoder18_FC |Epoch:  41 | train loss: 0.0102
# Model:  Autoencoder18_FC |Epoch:  42 | train loss: 0.0103
# Model:  Autoencoder18_FC |Epoch:  43 | train loss: 0.0095
# Model:  Autoencoder18_FC |Epoch:  44 | train loss: 0.0103
# Model:  Autoencoder18_FC |Epoch:  45 | train loss: 0.0102
# Model:  Autoencoder18_FC |Epoch:  46 | train loss: 0.0100
# Model:  Autoencoder18_FC |Epoch:  47 | train loss: 0.0103
# Model:  Autoencoder18_FC |Epoch:  48 | train loss: 0.0109
# Model:  Autoencoder18_FC |Epoch:  49 | train loss: 0.0093
# Model:  Autoencoder18_FC |Epoch:  50 | train loss: 0.0097
# Model:  Autoencoder18_FC |Epoch:  51 | train loss: 0.0104
# Model:  Autoencoder18_FC |Epoch:  52 | train loss: 0.0103
# Model:  Autoencoder18_FC |Epoch:  53 | train loss: 0.0094
# Model:  Autoencoder18_FC |Epoch:  54 | train loss: 0.0094
# Model:  Autoencoder18_FC |Epoch:  55 | train loss: 0.0098
# Model:  Autoencoder18_FC |Epoch:  56 | train loss: 0.0097
# Model:  Autoencoder18_FC |Epoch:  57 | train loss: 0.0095
# Model:  Autoencoder18_FC |Epoch:  58 | train loss: 0.0101
# Model:  Autoencoder18_FC |Epoch:  59 | train loss: 0.0101
# Model:  Autoencoder18_FC |Epoch:  60 | train loss: 0.0095
# Model:  Autoencoder18_FC |Epoch:  61 | train loss: 0.0097
# Model:  Autoencoder18_FC |Epoch:  62 | train loss: 0.0090
# Model:  Autoencoder18_FC |Epoch:  63 | train loss: 0.0098
# Model:  Autoencoder18_FC |Epoch:  64 | train loss: 0.0091
# Model:  Autoencoder18_FC |Epoch:  65 | train loss: 0.0100
# Model:  Autoencoder18_FC |Epoch:  66 | train loss: 0.0098
# Model:  Autoencoder18_FC |Epoch:  67 | train loss: 0.0093
# Model:  Autoencoder18_FC |Epoch:  68 | train loss: 0.0098
# Model:  Autoencoder18_FC |Epoch:  69 | train loss: 0.0094
# Model:  Autoencoder18_FC |Epoch:  70 | train loss: 0.0091
# Model:  Autoencoder18_FC |Epoch:  71 | train loss: 0.0100
# Model:  Autoencoder18_FC |Epoch:  72 | train loss: 0.0097
# Model:  Autoencoder18_FC |Epoch:  73 | train loss: 0.0098
# Model:  Autoencoder18_FC |Epoch:  74 | train loss: 0.0095
# Model:  Autoencoder18_FC |Epoch:  75 | train loss: 0.0089
# Model:  Autoencoder18_FC |Epoch:  76 | train loss: 0.0096
# Model:  Autoencoder18_FC |Epoch:  77 | train loss: 0.0091
# Model:  Autoencoder18_FC |Epoch:  78 | train loss: 0.0092
# Model:  Autoencoder18_FC |Epoch:  79 | train loss: 0.0096
# Model:  Autoencoder18_FC |Epoch:  80 | train loss: 0.0090
# Model:  Autoencoder18_FC |Epoch:  81 | train loss: 0.0095
# Model:  Autoencoder18_FC |Epoch:  82 | train loss: 0.0096
# Model:  Autoencoder18_FC |Epoch:  83 | train loss: 0.0097
# Model:  Autoencoder18_FC |Epoch:  84 | train loss: 0.0091
# Model:  Autoencoder18_FC |Epoch:  85 | train loss: 0.0093
# Model:  Autoencoder18_FC |Epoch:  86 | train loss: 0.0090
# Model:  Autoencoder18_FC |Epoch:  87 | train loss: 0.0092
# Model:  Autoencoder18_FC |Epoch:  88 | train loss: 0.0089
# Model:  Autoencoder18_FC |Epoch:  89 | train loss: 0.0098
# Model:  Autoencoder18_FC |Epoch:  90 | train loss: 0.0090
# Model:  Autoencoder18_FC |Epoch:  91 | train loss: 0.0088
# Model:  Autoencoder18_FC |Epoch:  92 | train loss: 0.0093
# Model:  Autoencoder18_FC |Epoch:  93 | train loss: 0.0090
# Model:  Autoencoder18_FC |Epoch:  94 | train loss: 0.0089
# Model:  Autoencoder18_FC |Epoch:  95 | train loss: 0.0088
# Model:  Autoencoder18_FC |Epoch:  96 | train loss: 0.0090
# Model:  Autoencoder18_FC |Epoch:  97 | train loss: 0.0093
# Model:  Autoencoder18_FC |Epoch:  98 | train loss: 0.0090
# Model:  Autoencoder18_FC |Epoch:  99 | train loss: 0.0091
# finish training!
# 2020-05-13 10:14:54.384329
# Model:  Autoencoder18_FC |train loss: 0.0094
# Model:  Autoencoder18_FC |validation loss: 0.0083
# 2020-05-13 10:14:58.827673
# Model:  Autoencoder18_FC |Epoch:  0 | train loss: 0.0339
# Model:  Autoencoder18_FC |Epoch:  1 | train loss: 0.0070
# Model:  Autoencoder18_FC |Epoch:  2 | train loss: 0.0057
# Model:  Autoencoder18_FC |Epoch:  3 | train loss: 0.0051
# Model:  Autoencoder18_FC |Epoch:  4 | train loss: 0.0048
# Model:  Autoencoder18_FC |Epoch:  5 | train loss: 0.0047
# Model:  Autoencoder18_FC |Epoch:  6 | train loss: 0.0046
# Model:  Autoencoder18_FC |Epoch:  7 | train loss: 0.0044
# Model:  Autoencoder18_FC |Epoch:  8 | train loss: 0.0044
# Model:  Autoencoder18_FC |Epoch:  9 | train loss: 0.0042
# Model:  Autoencoder18_FC |Epoch:  10 | train loss: 0.0041
# Model:  Autoencoder18_FC |Epoch:  11 | train loss: 0.0040
# Model:  Autoencoder18_FC |Epoch:  12 | train loss: 0.0039
# Model:  Autoencoder18_FC |Epoch:  13 | train loss: 0.0038
# Model:  Autoencoder18_FC |Epoch:  14 | train loss: 0.0040
# Model:  Autoencoder18_FC |Epoch:  15 | train loss: 0.0037
# Model:  Autoencoder18_FC |Epoch:  16 | train loss: 0.0038
# Model:  Autoencoder18_FC |Epoch:  17 | train loss: 0.0039
# Model:  Autoencoder18_FC |Epoch:  18 | train loss: 0.0036
# Model:  Autoencoder18_FC |Epoch:  19 | train loss: 0.0035
# Model:  Autoencoder18_FC |Epoch:  20 | train loss: 0.0035
# Model:  Autoencoder18_FC |Epoch:  21 | train loss: 0.0034
# Model:  Autoencoder18_FC |Epoch:  22 | train loss: 0.0034
# Model:  Autoencoder18_FC |Epoch:  23 | train loss: 0.0033
# Model:  Autoencoder18_FC |Epoch:  24 | train loss: 0.0032
# Model:  Autoencoder18_FC |Epoch:  25 | train loss: 0.0032
# Model:  Autoencoder18_FC |Epoch:  26 | train loss: 0.0032
# Model:  Autoencoder18_FC |Epoch:  27 | train loss: 0.0035
# Model:  Autoencoder18_FC |Epoch:  28 | train loss: 0.0033
# Model:  Autoencoder18_FC |Epoch:  29 | train loss: 0.0032
# Model:  Autoencoder18_FC |Epoch:  30 | train loss: 0.0031
# Model:  Autoencoder18_FC |Epoch:  31 | train loss: 0.0031
# Model:  Autoencoder18_FC |Epoch:  32 | train loss: 0.0031
# Model:  Autoencoder18_FC |Epoch:  33 | train loss: 0.0030
# Model:  Autoencoder18_FC |Epoch:  34 | train loss: 0.0030
# Model:  Autoencoder18_FC |Epoch:  35 | train loss: 0.0028
# Model:  Autoencoder18_FC |Epoch:  36 | train loss: 0.0028
# Model:  Autoencoder18_FC |Epoch:  37 | train loss: 0.0028
# Model:  Autoencoder18_FC |Epoch:  38 | train loss: 0.0027
# Model:  Autoencoder18_FC |Epoch:  39 | train loss: 0.0027
# Model:  Autoencoder18_FC |Epoch:  40 | train loss: 0.0027
# Model:  Autoencoder18_FC |Epoch:  41 | train loss: 0.0027
# Model:  Autoencoder18_FC |Epoch:  42 | train loss: 0.0026
# Model:  Autoencoder18_FC |Epoch:  43 | train loss: 0.0026
# Model:  Autoencoder18_FC |Epoch:  44 | train loss: 0.0026
# Model:  Autoencoder18_FC |Epoch:  45 | train loss: 0.0026
# Model:  Autoencoder18_FC |Epoch:  46 | train loss: 0.0026
# Model:  Autoencoder18_FC |Epoch:  47 | train loss: 0.0028
# Model:  Autoencoder18_FC |Epoch:  48 | train loss: 0.0025
# Model:  Autoencoder18_FC |Epoch:  49 | train loss: 0.0025
# Model:  Autoencoder18_FC |Epoch:  50 | train loss: 0.0025
# Model:  Autoencoder18_FC |Epoch:  51 | train loss: 0.0024
# Model:  Autoencoder18_FC |Epoch:  52 | train loss: 0.0024
# Model:  Autoencoder18_FC |Epoch:  53 | train loss: 0.0024
# Model:  Autoencoder18_FC |Epoch:  54 | train loss: 0.0023
# Model:  Autoencoder18_FC |Epoch:  55 | train loss: 0.0023
# Model:  Autoencoder18_FC |Epoch:  56 | train loss: 0.0023
# Model:  Autoencoder18_FC |Epoch:  57 | train loss: 0.0023
# Model:  Autoencoder18_FC |Epoch:  58 | train loss: 0.0023
# Model:  Autoencoder18_FC |Epoch:  59 | train loss: 0.0022
# Model:  Autoencoder18_FC |Epoch:  60 | train loss: 0.0022
# Model:  Autoencoder18_FC |Epoch:  61 | train loss: 0.0022
# Model:  Autoencoder18_FC |Epoch:  62 | train loss: 0.0022
# Model:  Autoencoder18_FC |Epoch:  63 | train loss: 0.0023
# Model:  Autoencoder18_FC |Epoch:  64 | train loss: 0.0023
# Model:  Autoencoder18_FC |Epoch:  65 | train loss: 0.0022
# Model:  Autoencoder18_FC |Epoch:  66 | train loss: 0.0023
# Model:  Autoencoder18_FC |Epoch:  67 | train loss: 0.0022
# Model:  Autoencoder18_FC |Epoch:  68 | train loss: 0.0022
# Model:  Autoencoder18_FC |Epoch:  69 | train loss: 0.0022
# Model:  Autoencoder18_FC |Epoch:  70 | train loss: 0.0022
# Model:  Autoencoder18_FC |Epoch:  71 | train loss: 0.0021
# Model:  Autoencoder18_FC |Epoch:  72 | train loss: 0.0020
# Model:  Autoencoder18_FC |Epoch:  73 | train loss: 0.0020
# Model:  Autoencoder18_FC |Epoch:  74 | train loss: 0.0020
# Model:  Autoencoder18_FC |Epoch:  75 | train loss: 0.0020
# Model:  Autoencoder18_FC |Epoch:  76 | train loss: 0.0021
# Model:  Autoencoder18_FC |Epoch:  77 | train loss: 0.0020
# Model:  Autoencoder18_FC |Epoch:  78 | train loss: 0.0020
# Model:  Autoencoder18_FC |Epoch:  79 | train loss: 0.0020
# Model:  Autoencoder18_FC |Epoch:  80 | train loss: 0.0021
# Model:  Autoencoder18_FC |Epoch:  81 | train loss: 0.0021
# Model:  Autoencoder18_FC |Epoch:  82 | train loss: 0.0019
# Model:  Autoencoder18_FC |Epoch:  83 | train loss: 0.0019
# Model:  Autoencoder18_FC |Epoch:  84 | train loss: 0.0019
# Model:  Autoencoder18_FC |Epoch:  85 | train loss: 0.0018
# Model:  Autoencoder18_FC |Epoch:  86 | train loss: 0.0018
# Model:  Autoencoder18_FC |Epoch:  87 | train loss: 0.0018
# Model:  Autoencoder18_FC |Epoch:  88 | train loss: 0.0018
# Model:  Autoencoder18_FC |Epoch:  89 | train loss: 0.0019
# Model:  Autoencoder18_FC |Epoch:  90 | train loss: 0.0019
# Model:  Autoencoder18_FC |Epoch:  91 | train loss: 0.0018
# Model:  Autoencoder18_FC |Epoch:  92 | train loss: 0.0018
# Model:  Autoencoder18_FC |Epoch:  93 | train loss: 0.0018
# Model:  Autoencoder18_FC |Epoch:  94 | train loss: 0.0017
# Model:  Autoencoder18_FC |Epoch:  95 | train loss: 0.0017
# Model:  Autoencoder18_FC |Epoch:  96 | train loss: 0.0017
# Model:  Autoencoder18_FC |Epoch:  97 | train loss: 0.0018
# Model:  Autoencoder18_FC |Epoch:  98 | train loss: 0.0017
# Model:  Autoencoder18_FC |Epoch:  99 | train loss: 0.0017
# finish training!
# 2020-05-13 10:31:45.636713
# Model:  Autoencoder18_FC |train loss: 0.0018
# Model:  Autoencoder18_FC |validation loss: 0.0010
# 2020-05-13 10:31:50.525708
# Model:  Autoencoder18_FC |Epoch:  0 | train loss: 0.0344
# Model:  Autoencoder18_FC |Epoch:  1 | train loss: 0.0075
# Model:  Autoencoder18_FC |Epoch:  2 | train loss: 0.0061
# Model:  Autoencoder18_FC |Epoch:  3 | train loss: 0.0056
# Model:  Autoencoder18_FC |Epoch:  4 | train loss: 0.0053
# Model:  Autoencoder18_FC |Epoch:  5 | train loss: 0.0052
# Model:  Autoencoder18_FC |Epoch:  6 | train loss: 0.0050
# Model:  Autoencoder18_FC |Epoch:  7 | train loss: 0.0047
# Model:  Autoencoder18_FC |Epoch:  8 | train loss: 0.0047
# Model:  Autoencoder18_FC |Epoch:  9 | train loss: 0.0045
# Model:  Autoencoder18_FC |Epoch:  10 | train loss: 0.0044
# Model:  Autoencoder18_FC |Epoch:  11 | train loss: 0.0043
# Model:  Autoencoder18_FC |Epoch:  12 | train loss: 0.0046
# Model:  Autoencoder18_FC |Epoch:  13 | train loss: 0.0042
# Model:  Autoencoder18_FC |Epoch:  14 | train loss: 0.0042
# Model:  Autoencoder18_FC |Epoch:  15 | train loss: 0.0042
# Model:  Autoencoder18_FC |Epoch:  16 | train loss: 0.0040
# Model:  Autoencoder18_FC |Epoch:  17 | train loss: 0.0039
# Model:  Autoencoder18_FC |Epoch:  18 | train loss: 0.0041
# Model:  Autoencoder18_FC |Epoch:  19 | train loss: 0.0039
# Model:  Autoencoder18_FC |Epoch:  20 | train loss: 0.0038
# Model:  Autoencoder18_FC |Epoch:  21 | train loss: 0.0038
# Model:  Autoencoder18_FC |Epoch:  22 | train loss: 0.0038
# Model:  Autoencoder18_FC |Epoch:  23 | train loss: 0.0038
# Model:  Autoencoder18_FC |Epoch:  24 | train loss: 0.0040
# Model:  Autoencoder18_FC |Epoch:  25 | train loss: 0.0037
# Model:  Autoencoder18_FC |Epoch:  26 | train loss: 0.0035
# Model:  Autoencoder18_FC |Epoch:  27 | train loss: 0.0035
# Model:  Autoencoder18_FC |Epoch:  28 | train loss: 0.0034
# Model:  Autoencoder18_FC |Epoch:  29 | train loss: 0.0034
# Model:  Autoencoder18_FC |Epoch:  30 | train loss: 0.0033
# Model:  Autoencoder18_FC |Epoch:  31 | train loss: 0.0034
# Model:  Autoencoder18_FC |Epoch:  32 | train loss: 0.0033
# Model:  Autoencoder18_FC |Epoch:  33 | train loss: 0.0033
# Model:  Autoencoder18_FC |Epoch:  34 | train loss: 0.0037
# Model:  Autoencoder18_FC |Epoch:  35 | train loss: 0.0034
# Model:  Autoencoder18_FC |Epoch:  36 | train loss: 0.0032
# Model:  Autoencoder18_FC |Epoch:  37 | train loss: 0.0031
# Model:  Autoencoder18_FC |Epoch:  38 | train loss: 0.0031
# Model:  Autoencoder18_FC |Epoch:  39 | train loss: 0.0031
# Model:  Autoencoder18_FC |Epoch:  40 | train loss: 0.0033
# Model:  Autoencoder18_FC |Epoch:  41 | train loss: 0.0033
# Model:  Autoencoder18_FC |Epoch:  42 | train loss: 0.0034
# Model:  Autoencoder18_FC |Epoch:  43 | train loss: 0.0032
# Model:  Autoencoder18_FC |Epoch:  44 | train loss: 0.0031
# Model:  Autoencoder18_FC |Epoch:  45 | train loss: 0.0030
# Model:  Autoencoder18_FC |Epoch:  46 | train loss: 0.0030
# Model:  Autoencoder18_FC |Epoch:  47 | train loss: 0.0033
# Model:  Autoencoder18_FC |Epoch:  48 | train loss: 0.0032
# Model:  Autoencoder18_FC |Epoch:  49 | train loss: 0.0029
# Model:  Autoencoder18_FC |Epoch:  50 | train loss: 0.0029
# Model:  Autoencoder18_FC |Epoch:  51 | train loss: 0.0029
# Model:  Autoencoder18_FC |Epoch:  52 | train loss: 0.0028
# Model:  Autoencoder18_FC |Epoch:  53 | train loss: 0.0027
# Model:  Autoencoder18_FC |Epoch:  54 | train loss: 0.0027
# Model:  Autoencoder18_FC |Epoch:  55 | train loss: 0.0027
# Model:  Autoencoder18_FC |Epoch:  56 | train loss: 0.0027
# Model:  Autoencoder18_FC |Epoch:  57 | train loss: 0.0026
# Model:  Autoencoder18_FC |Epoch:  58 | train loss: 0.0026
# Model:  Autoencoder18_FC |Epoch:  59 | train loss: 0.0027
# Model:  Autoencoder18_FC |Epoch:  60 | train loss: 0.0026
# Model:  Autoencoder18_FC |Epoch:  61 | train loss: 0.0025
# Model:  Autoencoder18_FC |Epoch:  62 | train loss: 0.0025
# Model:  Autoencoder18_FC |Epoch:  63 | train loss: 0.0025
# Model:  Autoencoder18_FC |Epoch:  64 | train loss: 0.0025
# Model:  Autoencoder18_FC |Epoch:  65 | train loss: 0.0026
# Model:  Autoencoder18_FC |Epoch:  66 | train loss: 0.0025
# Model:  Autoencoder18_FC |Epoch:  67 | train loss: 0.0025
# Model:  Autoencoder18_FC |Epoch:  68 | train loss: 0.0027
# Model:  Autoencoder18_FC |Epoch:  69 | train loss: 0.0025
# Model:  Autoencoder18_FC |Epoch:  70 | train loss: 0.0026
# Model:  Autoencoder18_FC |Epoch:  71 | train loss: 0.0025
# Model:  Autoencoder18_FC |Epoch:  72 | train loss: 0.0024
# Model:  Autoencoder18_FC |Epoch:  73 | train loss: 0.0024
# Model:  Autoencoder18_FC |Epoch:  74 | train loss: 0.0024
# Model:  Autoencoder18_FC |Epoch:  75 | train loss: 0.0024
# Model:  Autoencoder18_FC |Epoch:  76 | train loss: 0.0024
# Model:  Autoencoder18_FC |Epoch:  77 | train loss: 0.0024
# Model:  Autoencoder18_FC |Epoch:  78 | train loss: 0.0023
# Model:  Autoencoder18_FC |Epoch:  79 | train loss: 0.0022
# Model:  Autoencoder18_FC |Epoch:  80 | train loss: 0.0022
# Model:  Autoencoder18_FC |Epoch:  81 | train loss: 0.0022
# Model:  Autoencoder18_FC |Epoch:  82 | train loss: 0.0022
# Model:  Autoencoder18_FC |Epoch:  83 | train loss: 0.0022
# Model:  Autoencoder18_FC |Epoch:  84 | train loss: 0.0022
# Model:  Autoencoder18_FC |Epoch:  85 | train loss: 0.0022
# Model:  Autoencoder18_FC |Epoch:  86 | train loss: 0.0023
# Model:  Autoencoder18_FC |Epoch:  87 | train loss: 0.0021
# Model:  Autoencoder18_FC |Epoch:  88 | train loss: 0.0021
# Model:  Autoencoder18_FC |Epoch:  89 | train loss: 0.0021
# Model:  Autoencoder18_FC |Epoch:  90 | train loss: 0.0022
# Model:  Autoencoder18_FC |Epoch:  91 | train loss: 0.0021
# Model:  Autoencoder18_FC |Epoch:  92 | train loss: 0.0021
# Model:  Autoencoder18_FC |Epoch:  93 | train loss: 0.0021
# Model:  Autoencoder18_FC |Epoch:  94 | train loss: 0.0020
# Model:  Autoencoder18_FC |Epoch:  95 | train loss: 0.0021
# Model:  Autoencoder18_FC |Epoch:  96 | train loss: 0.0021
# Model:  Autoencoder18_FC |Epoch:  97 | train loss: 0.0020
# Model:  Autoencoder18_FC |Epoch:  98 | train loss: 0.0022
# Model:  Autoencoder18_FC |Epoch:  99 | train loss: 0.0022
# finish training!
# 2020-05-13 10:48:28.395596
# Model:  Autoencoder18_FC |train loss: 0.0023
# Model:  Autoencoder18_FC |validation loss: 0.0024
# 2020-05-13 10:48:34.120138
# Model:  Autoencoder18_FC |Epoch:  0 | train loss: 0.0358
# Model:  Autoencoder18_FC |Epoch:  1 | train loss: 0.0086
# Model:  Autoencoder18_FC |Epoch:  2 | train loss: 0.0070
# Model:  Autoencoder18_FC |Epoch:  3 | train loss: 0.0064
# Model:  Autoencoder18_FC |Epoch:  4 | train loss: 0.0062
# Model:  Autoencoder18_FC |Epoch:  5 | train loss: 0.0058
# Model:  Autoencoder18_FC |Epoch:  6 | train loss: 0.0058
# Model:  Autoencoder18_FC |Epoch:  7 | train loss: 0.0055
# Model:  Autoencoder18_FC |Epoch:  8 | train loss: 0.0053
# Model:  Autoencoder18_FC |Epoch:  9 | train loss: 0.0052
# Model:  Autoencoder18_FC |Epoch:  10 | train loss: 0.0051
# Model:  Autoencoder18_FC |Epoch:  11 | train loss: 0.0050
# Model:  Autoencoder18_FC |Epoch:  12 | train loss: 0.0050
# Model:  Autoencoder18_FC |Epoch:  13 | train loss: 0.0051
# Model:  Autoencoder18_FC |Epoch:  14 | train loss: 0.0048
# Model:  Autoencoder18_FC |Epoch:  15 | train loss: 0.0047
# Model:  Autoencoder18_FC |Epoch:  16 | train loss: 0.0046
# Model:  Autoencoder18_FC |Epoch:  17 | train loss: 0.0046
# Model:  Autoencoder18_FC |Epoch:  18 | train loss: 0.0046
# Model:  Autoencoder18_FC |Epoch:  19 | train loss: 0.0046
# Model:  Autoencoder18_FC |Epoch:  20 | train loss: 0.0044
# Model:  Autoencoder18_FC |Epoch:  21 | train loss: 0.0043
# Model:  Autoencoder18_FC |Epoch:  22 | train loss: 0.0043
# Model:  Autoencoder18_FC |Epoch:  23 | train loss: 0.0043
# Model:  Autoencoder18_FC |Epoch:  24 | train loss: 0.0043
# Model:  Autoencoder18_FC |Epoch:  25 | train loss: 0.0042
# Model:  Autoencoder18_FC |Epoch:  26 | train loss: 0.0042
# Model:  Autoencoder18_FC |Epoch:  27 | train loss: 0.0041
# Model:  Autoencoder18_FC |Epoch:  28 | train loss: 0.0041
# Model:  Autoencoder18_FC |Epoch:  29 | train loss: 0.0040
# Model:  Autoencoder18_FC |Epoch:  30 | train loss: 0.0039
# Model:  Autoencoder18_FC |Epoch:  31 | train loss: 0.0041
# Model:  Autoencoder18_FC |Epoch:  32 | train loss: 0.0040
# Model:  Autoencoder18_FC |Epoch:  33 | train loss: 0.0038
# Model:  Autoencoder18_FC |Epoch:  34 | train loss: 0.0038
# Model:  Autoencoder18_FC |Epoch:  35 | train loss: 0.0037
# Model:  Autoencoder18_FC |Epoch:  36 | train loss: 0.0038
# Model:  Autoencoder18_FC |Epoch:  37 | train loss: 0.0037
# Model:  Autoencoder18_FC |Epoch:  38 | train loss: 0.0038
# Model:  Autoencoder18_FC |Epoch:  39 | train loss: 0.0039
# Model:  Autoencoder18_FC |Epoch:  40 | train loss: 0.0037
# Model:  Autoencoder18_FC |Epoch:  41 | train loss: 0.0036
# Model:  Autoencoder18_FC |Epoch:  42 | train loss: 0.0036
# Model:  Autoencoder18_FC |Epoch:  43 | train loss: 0.0035
# Model:  Autoencoder18_FC |Epoch:  44 | train loss: 0.0035
# Model:  Autoencoder18_FC |Epoch:  45 | train loss: 0.0034
# Model:  Autoencoder18_FC |Epoch:  46 | train loss: 0.0033
# Model:  Autoencoder18_FC |Epoch:  47 | train loss: 0.0034
# Model:  Autoencoder18_FC |Epoch:  48 | train loss: 0.0033
# Model:  Autoencoder18_FC |Epoch:  49 | train loss: 0.0032
# Model:  Autoencoder18_FC |Epoch:  50 | train loss: 0.0032
# Model:  Autoencoder18_FC |Epoch:  51 | train loss: 0.0032
# Model:  Autoencoder18_FC |Epoch:  52 | train loss: 0.0032
# Model:  Autoencoder18_FC |Epoch:  53 | train loss: 0.0033
# Model:  Autoencoder18_FC |Epoch:  54 | train loss: 0.0033
# Model:  Autoencoder18_FC |Epoch:  55 | train loss: 0.0033
# Model:  Autoencoder18_FC |Epoch:  56 | train loss: 0.0034
# Model:  Autoencoder18_FC |Epoch:  57 | train loss: 0.0034
# Model:  Autoencoder18_FC |Epoch:  58 | train loss: 0.0033
# Model:  Autoencoder18_FC |Epoch:  59 | train loss: 0.0031
# Model:  Autoencoder18_FC |Epoch:  60 | train loss: 0.0031
# Model:  Autoencoder18_FC |Epoch:  61 | train loss: 0.0031
# Model:  Autoencoder18_FC |Epoch:  62 | train loss: 0.0032
# Model:  Autoencoder18_FC |Epoch:  63 | train loss: 0.0031
# Model:  Autoencoder18_FC |Epoch:  64 | train loss: 0.0031
# Model:  Autoencoder18_FC |Epoch:  65 | train loss: 0.0031
# Model:  Autoencoder18_FC |Epoch:  66 | train loss: 0.0032
# Model:  Autoencoder18_FC |Epoch:  67 | train loss: 0.0031
# Model:  Autoencoder18_FC |Epoch:  68 | train loss: 0.0030
# Model:  Autoencoder18_FC |Epoch:  69 | train loss: 0.0029
# Model:  Autoencoder18_FC |Epoch:  70 | train loss: 0.0030
# Model:  Autoencoder18_FC |Epoch:  71 | train loss: 0.0029
# Model:  Autoencoder18_FC |Epoch:  72 | train loss: 0.0029
# Model:  Autoencoder18_FC |Epoch:  73 | train loss: 0.0028
# Model:  Autoencoder18_FC |Epoch:  74 | train loss: 0.0028
# Model:  Autoencoder18_FC |Epoch:  75 | train loss: 0.0027
# Model:  Autoencoder18_FC |Epoch:  76 | train loss: 0.0028
# Model:  Autoencoder18_FC |Epoch:  77 | train loss: 0.0027
# Model:  Autoencoder18_FC |Epoch:  78 | train loss: 0.0027
# Model:  Autoencoder18_FC |Epoch:  79 | train loss: 0.0027
# Model:  Autoencoder18_FC |Epoch:  80 | train loss: 0.0027
# Model:  Autoencoder18_FC |Epoch:  81 | train loss: 0.0026
# Model:  Autoencoder18_FC |Epoch:  82 | train loss: 0.0026
# Model:  Autoencoder18_FC |Epoch:  83 | train loss: 0.0026
# Model:  Autoencoder18_FC |Epoch:  84 | train loss: 0.0025
# Model:  Autoencoder18_FC |Epoch:  85 | train loss: 0.0026
# Model:  Autoencoder18_FC |Epoch:  86 | train loss: 0.0026
# Model:  Autoencoder18_FC |Epoch:  87 | train loss: 0.0025
# Model:  Autoencoder18_FC |Epoch:  88 | train loss: 0.0025
# Model:  Autoencoder18_FC |Epoch:  89 | train loss: 0.0025
# Model:  Autoencoder18_FC |Epoch:  90 | train loss: 0.0025
# Model:  Autoencoder18_FC |Epoch:  91 | train loss: 0.0025
# Model:  Autoencoder18_FC |Epoch:  92 | train loss: 0.0025
# Model:  Autoencoder18_FC |Epoch:  93 | train loss: 0.0026
# Model:  Autoencoder18_FC |Epoch:  94 | train loss: 0.0024
# Model:  Autoencoder18_FC |Epoch:  95 | train loss: 0.0025
# Model:  Autoencoder18_FC |Epoch:  96 | train loss: 0.0024
# Model:  Autoencoder18_FC |Epoch:  97 | train loss: 0.0024
# Model:  Autoencoder18_FC |Epoch:  98 | train loss: 0.0023
# Model:  Autoencoder18_FC |Epoch:  99 | train loss: 0.0024
# finish training!
# 2020-05-13 11:05:16.319249
# Model:  Autoencoder18_FC |train loss: 0.0025
# Model:  Autoencoder18_FC |validation loss: 0.0015
# 2020-05-13 11:05:21.014702
# Model:  Autoencoder18_FC |Epoch:  0 | train loss: 0.0416
# Model:  Autoencoder18_FC |Epoch:  1 | train loss: 0.0105
# Model:  Autoencoder18_FC |Epoch:  2 | train loss: 0.0089
# Model:  Autoencoder18_FC |Epoch:  3 | train loss: 0.0081
# Model:  Autoencoder18_FC |Epoch:  4 | train loss: 0.0079
# ...
# Model:  Autoencoder18_FC |Epoch:  32 | train loss: 0.0143
# Model:  Autoencoder18_FC |Epoch:  33 | train loss: 0.0147
# Model:  Autoencoder18_FC |Epoch:  34 | train loss: 0.0142
# Model:  Autoencoder18_FC |Epoch:  35 | train loss: 0.0143
# Model:  Autoencoder18_FC |Epoch:  36 | train loss: 0.0147
# Model:  Autoencoder18_FC |Epoch:  37 | train loss: 0.0148
# Model:  Autoencoder18_FC |Epoch:  38 | train loss: 0.0137
# Model:  Autoencoder18_FC |Epoch:  39 | train loss: 0.0142
# Model:  Autoencoder18_FC |Epoch:  40 | train loss: 0.0139
# Model:  Autoencoder18_FC |Epoch:  41 | train loss: 0.0138
# Model:  Autoencoder18_FC |Epoch:  42 | train loss: 0.0141
# Model:  Autoencoder18_FC |Epoch:  43 | train loss: 0.0146
# Model:  Autoencoder18_FC |Epoch:  44 | train loss: 0.0139
# Model:  Autoencoder18_FC |Epoch:  45 | train loss: 0.0135
# Model:  Autoencoder18_FC |Epoch:  46 | train loss: 0.0140
# Model:  Autoencoder18_FC |Epoch:  47 | train loss: 0.0134
# Model:  Autoencoder18_FC |Epoch:  48 | train loss: 0.0130
# Model:  Autoencoder18_FC |Epoch:  49 | train loss: 0.0134
# Model:  Autoencoder18_FC |Epoch:  50 | train loss: 0.0131
# Model:  Autoencoder18_FC |Epoch:  51 | train loss: 0.0128
# Model:  Autoencoder18_FC |Epoch:  52 | train loss: 0.0128
# Model:  Autoencoder18_FC |Epoch:  53 | train loss: 0.0127
# Model:  Autoencoder18_FC |Epoch:  54 | train loss: 0.0129
# Model:  Autoencoder18_FC |Epoch:  55 | train loss: 0.0126
# Model:  Autoencoder18_FC |Epoch:  56 | train loss: 0.0134
# Model:  Autoencoder18_FC |Epoch:  57 | train loss: 0.0126
# Model:  Autoencoder18_FC |Epoch:  58 | train loss: 0.0126
# Model:  Autoencoder18_FC |Epoch:  59 | train loss: 0.0124
# Model:  Autoencoder18_FC |Epoch:  60 | train loss: 0.0132
# Model:  Autoencoder18_FC |Epoch:  61 | train loss: 0.0123
# Model:  Autoencoder18_FC |Epoch:  62 | train loss: 0.0129
# Model:  Autoencoder18_FC |Epoch:  63 | train loss: 0.0124
# Model:  Autoencoder18_FC |Epoch:  64 | train loss: 0.0122
# Model:  Autoencoder18_FC |Epoch:  65 | train loss: 0.0124
# Model:  Autoencoder18_FC |Epoch:  66 | train loss: 0.0127
# Model:  Autoencoder18_FC |Epoch:  67 | train loss: 0.0122
# Model:  Autoencoder18_FC |Epoch:  68 | train loss: 0.0124
# Model:  Autoencoder18_FC |Epoch:  69 | train loss: 0.0122
# Model:  Autoencoder18_FC |Epoch:  70 | train loss: 0.0122
# Model:  Autoencoder18_FC |Epoch:  71 | train loss: 0.0121
# Model:  Autoencoder18_FC |Epoch:  72 | train loss: 0.0120
# Model:  Autoencoder18_FC |Epoch:  73 | train loss: 0.0120
# Model:  Autoencoder18_FC |Epoch:  74 | train loss: 0.0119
# Model:  Autoencoder18_FC |Epoch:  75 | train loss: 0.0120
# Model:  Autoencoder18_FC |Epoch:  76 | train loss: 0.0119
# Model:  Autoencoder18_FC |Epoch:  77 | train loss: 0.0119
# Model:  Autoencoder18_FC |Epoch:  78 | train loss: 0.0126
# Model:  Autoencoder18_FC |Epoch:  79 | train loss: 0.0119
# Model:  Autoencoder18_FC |Epoch:  80 | train loss: 0.0117
# Model:  Autoencoder18_FC |Epoch:  81 | train loss: 0.0122
# Model:  Autoencoder18_FC |Epoch:  82 | train loss: 0.0117
# Model:  Autoencoder18_FC |Epoch:  83 | train loss: 0.0118
# Model:  Autoencoder18_FC |Epoch:  84 | train loss: 0.0118
# Model:  Autoencoder18_FC |Epoch:  85 | train loss: 0.0117
# Model:  Autoencoder18_FC |Epoch:  86 | train loss: 0.0118
# Model:  Autoencoder18_FC |Epoch:  87 | train loss: 0.0119
# Model:  Autoencoder18_FC |Epoch:  88 | train loss: 0.0116
# Model:  Autoencoder18_FC |Epoch:  89 | train loss: 0.0117
# Model:  Autoencoder18_FC |Epoch:  90 | train loss: 0.0116
# Model:  Autoencoder18_FC |Epoch:  91 | train loss: 0.0118
# Model:  Autoencoder18_FC |Epoch:  92 | train loss: 0.0120
# Model:  Autoencoder18_FC |Epoch:  93 | train loss: 0.0115
# Model:  Autoencoder18_FC |Epoch:  94 | train loss: 0.0116
# Model:  Autoencoder18_FC |Epoch:  95 | train loss: 0.0115
# Model:  Autoencoder18_FC |Epoch:  96 | train loss: 0.0114
# Model:  Autoencoder18_FC |Epoch:  97 | train loss: 0.0120
# Model:  Autoencoder18_FC |Epoch:  98 | train loss: 0.0117
# Model:  Autoencoder18_FC |Epoch:  99 | train loss: 0.0122
# finish training!
# 2020-05-13 15:15:49.237570
# Model:  Autoencoder18_FC |train loss: 0.0118
# Model:  Autoencoder18_FC |validation loss: 0.0090
# 2020-05-13 15:15:53.877695
# Model:  Autoencoder18_FC |Epoch:  0 | train loss: 2.9875
# Model:  Autoencoder18_FC |Epoch:  1 | train loss: 2.4690
# Model:  Autoencoder18_FC |Epoch:  2 | train loss: 2.0085
# Model:  Autoencoder18_FC |Epoch:  3 | train loss: 1.5760
# Model:  Autoencoder18_FC |Epoch:  4 | train loss: 1.1701
# Model:  Autoencoder18_FC |Epoch:  5 | train loss: 0.7916
# Model:  Autoencoder18_FC |Epoch:  6 | train loss: 0.4447
# Model:  Autoencoder18_FC |Epoch:  7 | train loss: 0.1405
# Model:  Autoencoder18_FC |Epoch:  8 | train loss: 0.0275
# Model:  Autoencoder18_FC |Epoch:  9 | train loss: 0.0244
# Model:  Autoencoder18_FC |Epoch:  10 | train loss: 0.0227
# Model:  Autoencoder18_FC |Epoch:  11 | train loss: 0.0218
# Model:  Autoencoder18_FC |Epoch:  12 | train loss: 0.0213
# Model:  Autoencoder18_FC |Epoch:  13 | train loss: 0.0207
# Model:  Autoencoder18_FC |Epoch:  14 | train loss: 0.0206
# Model:  Autoencoder18_FC |Epoch:  15 | train loss: 0.0198
# Model:  Autoencoder18_FC |Epoch:  16 | train loss: 0.0196
# Model:  Autoencoder18_FC |Epoch:  17 | train loss: 0.0192
# Model:  Autoencoder18_FC |Epoch:  18 | train loss: 0.0192
# Model:  Autoencoder18_FC |Epoch:  19 | train loss: 0.0185
# Model:  Autoencoder18_FC |Epoch:  20 | train loss: 0.0186
# Model:  Autoencoder18_FC |Epoch:  21 | train loss: 0.0187
# Model:  Autoencoder18_FC |Epoch:  22 | train loss: 0.0181
# Model:  Autoencoder18_FC |Epoch:  23 | train loss: 0.0178
# Model:  Autoencoder18_FC |Epoch:  24 | train loss: 0.0175
# Model:  Autoencoder18_FC |Epoch:  25 | train loss: 0.0173
# Model:  Autoencoder18_FC |Epoch:  26 | train loss: 0.0172
# Model:  Autoencoder18_FC |Epoch:  27 | train loss: 0.0173
# Model:  Autoencoder18_FC |Epoch:  28 | train loss: 0.0176
# Model:  Autoencoder18_FC |Epoch:  29 | train loss: 0.0173
# Model:  Autoencoder18_FC |Epoch:  30 | train loss: 0.0168
# Model:  Autoencoder18_FC |Epoch:  31 | train loss: 0.0164
# Model:  Autoencoder18_FC |Epoch:  32 | train loss: 0.0163
# Model:  Autoencoder18_FC |Epoch:  33 | train loss: 0.0160
# Model:  Autoencoder18_FC |Epoch:  34 | train loss: 0.0158
# Model:  Autoencoder18_FC |Epoch:  35 | train loss: 0.0157
# Model:  Autoencoder18_FC |Epoch:  36 | train loss: 0.0156
# Model:  Autoencoder18_FC |Epoch:  37 | train loss: 0.0157
# Model:  Autoencoder18_FC |Epoch:  38 | train loss: 0.0167
# Model:  Autoencoder18_FC |Epoch:  39 | train loss: 0.0153
# Model:  Autoencoder18_FC |Epoch:  40 | train loss: 0.0152
# Model:  Autoencoder18_FC |Epoch:  41 | train loss: 0.0161
# Model:  Autoencoder18_FC |Epoch:  42 | train loss: 0.0151
# Model:  Autoencoder18_FC |Epoch:  43 | train loss: 0.0152
# Model:  Autoencoder18_FC |Epoch:  44 | train loss: 0.0150
# Model:  Autoencoder18_FC |Epoch:  45 | train loss: 0.0149
# Model:  Autoencoder18_FC |Epoch:  46 | train loss: 0.0156
# Model:  Autoencoder18_FC |Epoch:  47 | train loss: 0.0149
# Model:  Autoencoder18_FC |Epoch:  48 | train loss: 0.0148
# Model:  Autoencoder18_FC |Epoch:  49 | train loss: 0.0147
# Model:  Autoencoder18_FC |Epoch:  50 | train loss: 0.0147
# Model:  Autoencoder18_FC |Epoch:  51 | train loss: 0.0145
# Model:  Autoencoder18_FC |Epoch:  52 | train loss: 0.0146
# Model:  Autoencoder18_FC |Epoch:  53 | train loss: 0.0156
# Model:  Autoencoder18_FC |Epoch:  54 | train loss: 0.0144
# Model:  Autoencoder18_FC |Epoch:  55 | train loss: 0.0144
# Model:  Autoencoder18_FC |Epoch:  56 | train loss: 0.0143
# Model:  Autoencoder18_FC |Epoch:  57 | train loss: 0.0143
# Model:  Autoencoder18_FC |Epoch:  58 | train loss: 0.0144
# Model:  Autoencoder18_FC |Epoch:  59 | train loss: 0.0146
# Model:  Autoencoder18_FC |Epoch:  60 | train loss: 0.0142
# Model:  Autoencoder18_FC |Epoch:  61 | train loss: 0.0143
# Model:  Autoencoder18_FC |Epoch:  62 | train loss: 0.0143
# Model:  Autoencoder18_FC |Epoch:  63 | train loss: 0.0141
# Model:  Autoencoder18_FC |Epoch:  64 | train loss: 0.0140
# Model:  Autoencoder18_FC |Epoch:  65 | train loss: 0.0141
# Model:  Autoencoder18_FC |Epoch:  66 | train loss: 0.0139
# Model:  Autoencoder18_FC |Epoch:  67 | train loss: 0.0139
# Model:  Autoencoder18_FC |Epoch:  68 | train loss: 0.0140
# Model:  Autoencoder18_FC |Epoch:  69 | train loss: 0.0141
# Model:  Autoencoder18_FC |Epoch:  70 | train loss: 0.0139
# Model:  Autoencoder18_FC |Epoch:  71 | train loss: 0.0138
# Model:  Autoencoder18_FC |Epoch:  72 | train loss: 0.0138
# Model:  Autoencoder18_FC |Epoch:  73 | train loss: 0.0137
# Model:  Autoencoder18_FC |Epoch:  74 | train loss: 0.0137
# Model:  Autoencoder18_FC |Epoch:  75 | train loss: 0.0137
# Model:  Autoencoder18_FC |Epoch:  76 | train loss: 0.0140
# Model:  Autoencoder18_FC |Epoch:  77 | train loss: 0.0145
# Model:  Autoencoder18_FC |Epoch:  78 | train loss: 0.0138
# Model:  Autoencoder18_FC |Epoch:  79 | train loss: 0.0135
# Model:  Autoencoder18_FC |Epoch:  80 | train loss: 0.0136
# Model:  Autoencoder18_FC |Epoch:  81 | train loss: 0.0136
# Model:  Autoencoder18_FC |Epoch:  82 | train loss: 0.0135
# Model:  Autoencoder18_FC |Epoch:  83 | train loss: 0.0139
# Model:  Autoencoder18_FC |Epoch:  84 | train loss: 0.0134
# Model:  Autoencoder18_FC |Epoch:  85 | train loss: 0.0134
# Model:  Autoencoder18_FC |Epoch:  86 | train loss: 0.0134
# Model:  Autoencoder18_FC |Epoch:  87 | train loss: 0.0139
# Model:  Autoencoder18_FC |Epoch:  88 | train loss: 0.0134
# Model:  Autoencoder18_FC |Epoch:  89 | train loss: 0.0134
# Model:  Autoencoder18_FC |Epoch:  90 | train loss: 0.0133
# Model:  Autoencoder18_FC |Epoch:  91 | train loss: 0.0132
# Model:  Autoencoder18_FC |Epoch:  92 | train loss: 0.0136
# Model:  Autoencoder18_FC |Epoch:  93 | train loss: 0.0134
# Model:  Autoencoder18_FC |Epoch:  94 | train loss: 0.0130
# Model:  Autoencoder18_FC |Epoch:  95 | train loss: 0.0131
# Model:  Autoencoder18_FC |Epoch:  96 | train loss: 0.0130
# Model:  Autoencoder18_FC |Epoch:  97 | train loss: 0.0142
# Model:  Autoencoder18_FC |Epoch:  98 | train loss: 0.0134
# Model:  Autoencoder18_FC |Epoch:  99 | train loss: 0.0132
# finish training!
# 2020-05-13 15:32:27.370982
# Model:  Autoencoder18_FC |train loss: 0.0144
# Model:  Autoencoder18_FC |validation loss: 0.0106
# 2020-05-13 15:32:33.173950
# Model:  Autoencoder18_FC |Epoch:  0 | train loss: 3.0107
# Model:  Autoencoder18_FC |Epoch:  1 | train loss: 2.4783
# Model:  Autoencoder18_FC |Epoch:  2 | train loss: 2.0164
# Model:  Autoencoder18_FC |Epoch:  3 | train loss: 1.5843
# Model:  Autoencoder18_FC |Epoch:  4 | train loss: 1.1793
# Model:  Autoencoder18_FC |Epoch:  5 | train loss: 0.7999
# Model:  Autoencoder18_FC |Epoch:  6 | train loss: 0.4524
# Model:  Autoencoder18_FC |Epoch:  7 | train loss: 0.1483
# Model:  Autoencoder18_FC |Epoch:  8 | train loss: 0.0272
# Model:  Autoencoder18_FC |Epoch:  9 | train loss: 0.0261
# Model:  Autoencoder18_FC |Epoch:  10 | train loss: 0.0257
# Model:  Autoencoder18_FC |Epoch:  11 | train loss: 0.0257
# Model:  Autoencoder18_FC |Epoch:  12 | train loss: 0.0255
# Model:  Autoencoder18_FC |Epoch:  13 | train loss: 0.0255
# Model:  Autoencoder18_FC |Epoch:  14 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  15 | train loss: 0.0253
# Model:  Autoencoder18_FC |Epoch:  16 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  17 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  18 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  19 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  20 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  21 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  22 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  23 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  24 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  25 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  26 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  27 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  28 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  29 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  30 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  31 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  32 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  33 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  34 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  35 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  36 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  37 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  38 | train loss: 0.0253
# Model:  Autoencoder18_FC |Epoch:  39 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  40 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  41 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  42 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  43 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  44 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  45 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  46 | train loss: 0.0255
# Model:  Autoencoder18_FC |Epoch:  47 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  48 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  49 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  50 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  51 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  52 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  53 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  54 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  55 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  56 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  57 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  58 | train loss: 0.0255
# Model:  Autoencoder18_FC |Epoch:  59 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  60 | train loss: 0.0255
# Model:  Autoencoder18_FC |Epoch:  61 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  62 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  63 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  64 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  65 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  66 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  67 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  68 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  69 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  70 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  71 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  72 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  73 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  74 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  75 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  76 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  77 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  78 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  79 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  80 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  81 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  82 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  83 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  84 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  85 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  86 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  87 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  88 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  89 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  90 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  91 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  92 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  93 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  94 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  95 | train loss: 0.0253
# Model:  Autoencoder18_FC |Epoch:  96 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  97 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  98 | train loss: 0.0254
# Model:  Autoencoder18_FC |Epoch:  99 | train loss: 0.0254
# finish training!
# 2020-05-13 15:49:11.818205
# Model:  Autoencoder18_FC |train loss: 0.0311
# Model:  Autoencoder18_FC |validation loss: 0.0342

# %%
#save nice RFs
tempmodel= Autoencoder18_FC()
tempmodel.load_state_dict(torch.load('out/ae_18_FC_lower_thresh_mse_'+str(17)+'.pth',map_location='cpu'))
tempmodel=tempmodel.to(device_cpu)
conv3d_0=tempmodel.conv1.weight.cpu().data.numpy()
def Save_conv3d_0(conv3d_0,filename):
    (outd,ind,_,_)=conv3d_0.shape
    fig, axes = plt.subplots(nrows=2, ncols=outd,figsize=(outd, 2))
    for jj in range(outd):
        weightmax=np.max(np.abs(conv3d_0[jj,...]))
        axes[0,jj].imshow(conv3d_0[jj,0,...],vmin=-weightmax,vmax=weightmax,cmap='bwr')#UV
        axes[0,jj].set_xticks([]),axes[0,jj].set_yticks([])
        im=axes[1,jj].imshow(conv3d_0[jj,1,...],vmin=-weightmax,vmax=weightmax,cmap='bwr')#G
        axes[1,jj].set_xticks([]),axes[1,jj].set_yticks([])
    
    #fig.subplots_adjust(right=0.8)
    #cbar_ax = fig.add_axes([0.82, 0.15, 0.01, 0.5]) #([0.85, 0.15, 0.03, 0.5])
    #ticks=np.linspace(weight_min,weight_max,4,endpoint=True)
    #fig.colorbar(im, cax=cbar_ax,ticks=ticks,format="%.4f")
    #fig.savefig(filename)
    
Save_conv3d_0(conv3d_0,'out_result/ae_18_FC_lower_thresh_mse_17_conv3d_0_bwr.svg')

# %%
#CC values
tempmodel= Autoencoder18_FC()
tempmodel.load_state_dict(torch.load('out/ae_18_FC_lower_thresh_mse_'+str(17)+'.pth',map_location='cpu'))
tempmodel=tempmodel.to(device_cpu)
conv3d_0=tempmodel.conv1.weight.cpu().data.numpy()
del tempmodel
(outd,ind,_,_)=conv3d_0.shape
CCs_lower_11=np.zeros(outd)
pVs_lower_11=np.zeros(outd)#p-value
for ii in range(outd):
    CCs_lower_11[ii],pVs_lower_11[ii]=pearsonr(conv3d_0[ii,0,...].flatten(),conv3d_0[ii,1,...].flatten())
print (CCs_lower_11)
print (pVs_lower_11)
# Out:
# [ 0.93105521  0.96797259 -0.01380726  0.92128217  0.94730182  0.85707466
#   0.97416218  0.99465714  0.90898742  0.99087602  0.84474347  0.88751722
#   0.94601582  0.99435851  0.99672826  0.86315816]
# [2.46408386e-36 3.52691168e-49 9.02629957e-01 3.82954526e-34
#  8.28311185e-41 1.82974710e-24 8.21411299e-53 1.11142202e-79
#  9.29612628e-32 1.56735323e-70 3.74836575e-23 2.61656939e-28
#  2.09428060e-40 9.47180419e-79 4.46168488e-88 3.70985050e-25]

# %%
#CC values for all models and list the indices with negative CC and pV <0.05
modelnames=np.arange(1,26)
for modelname in modelnames:
    tempmodel= Autoencoder18_FC()
    tempmodel.load_state_dict(torch.load('out/ae_18_FC_lower_thresh_mse_'+str(modelname)+'.pth',map_location='cpu'))
    tempmodel=tempmodel.to(device_cpu)
    conv3d_0=tempmodel.conv1.weight.cpu().data.numpy()
    del tempmodel
    (outd,ind,_,_)=conv3d_0.shape
    CCs_upper_7=np.zeros(outd)
    pVs_upper_7=np.zeros(outd)
    for ii in range(outd):
        CCs_upper_7[ii],pVs_upper_7[ii]=pearsonr(conv3d_0[ii,0,...].flatten(),conv3d_0[ii,1,...].flatten())
    print ('Model: %d' %(modelname))
    opp_ind=np.where(CCs_upper_7<0)[0].tolist()
    pV_ind =np.where(pVs_upper_7<0.05)[0].tolist()
    opp_vP_ind=[opp_ind,pV_ind]
    opp_pV=set(opp_vP_ind[0]).intersection(*opp_vP_ind)
    print (opp_pV)
    print ('/n')
# Out:
# Model: 1
# set()
# /n
# Model: 2
# set()
# /n
# Model: 3
# set()
# /n
# Model: 4
# set()
# /n
# Model: 5
# set()
# /n
# Model: 6
# set()
# /n
# Model: 7
# set()
# /n
# Model: 8
# set()
# /n
# Model: 9
# set()
# /n
# Model: 10
# set()
# /n
# Model: 11
# set()
# /n
# Model: 12
# set()
# /n
# Model: 13
# set()
# /n
# Model: 14
# set()
# /n
# Model: 15
# set()
# /n
# Model: 16
# set()
# /n
# Model: 17
# set()
# /n
# Model: 18
# set()
# /n
# Model: 19
# set()
# /n
# Model: 20
# {2}
# /n
# Model: 21
# set()
# /n
# Model: 22
# {3}
# /n
# Model: 23
# {3, 12, 15}
# /n
# Model: 24
# {0, 9}
# /n
# Model: 25
# set()
# /n
